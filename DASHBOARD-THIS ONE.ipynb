# %%
# !pip install dash==1.19.0  

# !pip install jupyter_dash 

# !pip install --upgrade plotly
# Out:
# Collecting dash==1.19.0
#   Downloading dash-1.19.0.tar.gz (75 kB)
#   Preparing metadata (setup.py) ... done
# Collecting Flask>=1.0.4 (from dash==1.19.0)
#   Downloading flask-3.1.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting flask-compress (from dash==1.19.0)
#   Downloading Flask_Compress-1.17-py3-none-any.whl.metadata (8.8 kB)
# Requirement already satisfied: plotly in /opt/conda/lib/python3.12/site-packages (from dash==1.19.0) (5.24.1)
# Collecting dash_renderer==1.9.0 (from dash==1.19.0)
#   Downloading dash_renderer-1.9.0.tar.gz (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 65.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting dash-core-components==1.15.0 (from dash==1.19.0)
#   Downloading dash_core_components-1.15.0.tar.gz (3.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 80.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting dash-html-components==1.1.2 (from dash==1.19.0)
#   Downloading dash_html_components-1.1.2.tar.gz (188 kB)
#   Preparing metadata (setup.py) ... done
# Collecting dash-table==4.11.2 (from dash==1.19.0)
#   Downloading dash_table-4.11.2.tar.gz (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 81.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting future (from dash==1.19.0)
#   Downloading future-1.0.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: Werkzeug>=3.1 in /opt/conda/lib/python3.12/site-packages (from Flask>=1.0.4->dash==1.19.0) (3.1.3)
# Requirement already satisfied: Jinja2>=3.1.2 in /opt/conda/lib/python3.12/site-packages (from Flask>=1.0.4->dash==1.19.0) (3.1.5)
# Collecting itsdangerous>=2.2 (from Flask>=1.0.4->dash==1.19.0)
#   Downloading itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting click>=8.1.3 (from Flask>=1.0.4->dash==1.19.0)
#   Downloading click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: blinker>=1.9 in /opt/conda/lib/python3.12/site-packages (from Flask>=1.0.4->dash==1.19.0) (1.9.0)
# Requirement already satisfied: brotli in /opt/conda/lib/python3.12/site-packages (from flask-compress->dash==1.19.0) (1.1.0)
# Requirement already satisfied: zstandard in /opt/conda/lib/python3.12/site-packages (from flask-compress->dash==1.19.0) (0.23.0)
# Requirement already satisfied: tenacity>=6.2.0 in /opt/conda/lib/python3.12/site-packages (from plotly->dash==1.19.0) (9.0.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.12/site-packages (from plotly->dash==1.19.0) (24.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.12/site-packages (from Jinja2>=3.1.2->Flask>=1.0.4->dash==1.19.0) (3.0.2)
# Downloading flask-3.1.0-py3-none-any.whl (102 kB)
# Downloading Flask_Compress-1.17-py3-none-any.whl (8.7 kB)
# Downloading future-1.0.0-py3-none-any.whl (491 kB)
# Downloading click-8.1.8-py3-none-any.whl (98 kB)
# Downloading itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Building wheels for collected packages: dash, dash-core-components, dash-html-components, dash_renderer, dash-table
#   Building wheel for dash (setup.py) ... one
#   Created wheel for dash: filename=dash-1.19.0-py3-none-any.whl size=84056 sha256=573562eb6857a192248eb9ebb9d048add2e46a42733a0829fa55a3ee22e5c617
#   Stored in directory: /home/jupyterlab/.cache/pip/wheels/1e/44/a1/f967f9b725ad97e257143699ff444863de3a55a66360f7fe46
#   Building wheel for dash-core-components (setup.py) ... one
#   Created wheel for dash-core-components: filename=dash_core_components-1.15.0-py3-none-any.whl size=3527013 sha256=db7b8125a5b8fed87de8d45fc9ef907e26b62a5ecc117f90f2ca169dc7cd64c5
#   Stored in directory: /home/jupyterlab/.cache/pip/wheels/6a/a1/bd/ecc107b05a332f46dbdab9f3325fed6ce94360ed5f7a255794
#   Building wheel for dash-html-components (setup.py) ... one
#   Created wheel for dash-html-components: filename=dash_html_components-1.1.2-py3-none-any.whl size=427860 sha256=fc10712c338371a196c399d56bac17b39f39f8db2582e3b4ea1e9f4adac9abde
#   Stored in directory: /home/jupyterlab/.cache/pip/wheels/c9/81/b4/150da76adfebe6b5e173950a50648ba52c8d4ce3396aede4c8
#   Building wheel for dash_renderer (setup.py) ... one
#   Created wheel for dash_renderer: filename=dash_renderer-1.9.0-py3-none-any.whl size=1014867 sha256=9b3429ca26a354d91b0b2c31ba56806ea212c8e3cd59a80d450369af7006f2aa
#   Stored in directory: /home/jupyterlab/.cache/pip/wheels/37/ed/88/9e5f26b7a4161de4603c5e913af0ec1b6a345840478cb2fd69
#   Building wheel for dash-table (setup.py) ... one
#   Created wheel for dash-table: filename=dash_table-4.11.2-py3-none-any.whl size=1839864 sha256=97151a558e245496a0341dcae9db59fd19c1a2047c70657e0f3047f437d86d2c
#   Stored in directory: /home/jupyterlab/.cache/pip/wheels/81/33/2c/eb7bd2194d1365d3645bf66fb94fdbd7355794b0a6307c651d
# Successfully built dash dash-core-components dash-html-components dash_renderer dash-table
# Installing collected packages: dash-table, dash_renderer, dash-html-components, dash-core-components, itsdangerous, future, click, Flask, flask-compress, dash
# Successfully installed Flask-3.1.0 click-8.1.8 dash-1.19.0 dash-core-components-1.15.0 dash-html-components-1.1.2 dash-table-4.11.2 dash_renderer-1.9.0 flask-compress-1.17 future-1.0.0 itsdangerous-2.2.0
# Collecting jupyter_dash
#   Downloading jupyter_dash-0.4.2-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: dash in /opt/conda/lib/python3.12/site-packages (from jupyter_dash) (1.19.0)
# Requirement already satisfied: requests in /opt/conda/lib/python3.12/site-packages (from jupyter_dash) (2.32.3)
# Requirement already satisfied: flask in /opt/conda/lib/python3.12/site-packages (from jupyter_dash) (3.1.0)
# Collecting retrying (from jupyter_dash)
#   Downloading retrying-1.3.4-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: ipython in /opt/conda/lib/python3.12/site-packages (from jupyter_dash) (8.31.0)
# Requirement already satisfied: ipykernel in /opt/conda/lib/python3.12/site-packages (from jupyter_dash) (6.29.5)
# Collecting ansi2html (from jupyter_dash)
#   Downloading ansi2html-1.9.2-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: nest-asyncio in /opt/conda/lib/python3.12/site-packages (from jupyter_dash) (1.6.0)
# Requirement already satisfied: flask-compress in /opt/conda/lib/python3.12/site-packages (from dash->jupyter_dash) (1.17)
# Requirement already satisfied: plotly in /opt/conda/lib/python3.12/site-packages (from dash->jupyter_dash) (5.24.1)
# Requirement already satisfied: dash_renderer==1.9.0 in /opt/conda/lib/python3.12/site-packages (from dash->jupyter_dash) (1.9.0)
# Requirement already satisfied: dash-core-components==1.15.0 in /opt/conda/lib/python3.12/site-packages (from dash->jupyter_dash) (1.15.0)
# Requirement already satisfied: dash-html-components==1.1.2 in /opt/conda/lib/python3.12/site-packages (from dash->jupyter_dash) (1.1.2)
# Requirement already satisfied: dash-table==4.11.2 in /opt/conda/lib/python3.12/site-packages (from dash->jupyter_dash) (4.11.2)
# Requirement already satisfied: future in /opt/conda/lib/python3.12/site-packages (from dash->jupyter_dash) (1.0.0)
# Requirement already satisfied: Werkzeug>=3.1 in /opt/conda/lib/python3.12/site-packages (from flask->jupyter_dash) (3.1.3)
# Requirement already satisfied: Jinja2>=3.1.2 in /opt/conda/lib/python3.12/site-packages (from flask->jupyter_dash) (3.1.5)
# Requirement already satisfied: itsdangerous>=2.2 in /opt/conda/lib/python3.12/site-packages (from flask->jupyter_dash) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in /opt/conda/lib/python3.12/site-packages (from flask->jupyter_dash) (8.1.8)
# Requirement already satisfied: blinker>=1.9 in /opt/conda/lib/python3.12/site-packages (from flask->jupyter_dash) (1.9.0)
# Requirement already satisfied: comm>=0.1.1 in /opt/conda/lib/python3.12/site-packages (from ipykernel->jupyter_dash) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /opt/conda/lib/python3.12/site-packages (from ipykernel->jupyter_dash) (1.8.12)
# Requirement already satisfied: jupyter-client>=6.1.12 in /opt/conda/lib/python3.12/site-packages (from ipykernel->jupyter_dash) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /opt/conda/lib/python3.12/site-packages (from ipykernel->jupyter_dash) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /opt/conda/lib/python3.12/site-packages (from ipykernel->jupyter_dash) (0.1.7)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.12/site-packages (from ipykernel->jupyter_dash) (24.2)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.12/site-packages (from ipykernel->jupyter_dash) (6.1.1)
# Requirement already satisfied: pyzmq>=24 in /opt/conda/lib/python3.12/site-packages (from ipykernel->jupyter_dash) (26.2.0)
# Requirement already satisfied: tornado>=6.1 in /opt/conda/lib/python3.12/site-packages (from ipykernel->jupyter_dash) (6.4.2)
# Requirement already satisfied: traitlets>=5.4.0 in /opt/conda/lib/python3.12/site-packages (from ipykernel->jupyter_dash) (5.14.3)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.12/site-packages (from ipython->jupyter_dash) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/lib/python3.12/site-packages (from ipython->jupyter_dash) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/lib/python3.12/site-packages (from ipython->jupyter_dash) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /opt/conda/lib/python3.12/site-packages (from ipython->jupyter_dash) (3.0.50)
# Requirement already satisfied: pygments>=2.4.0 in /opt/conda/lib/python3.12/site-packages (from ipython->jupyter_dash) (2.19.1)
# Requirement already satisfied: stack_data in /opt/conda/lib/python3.12/site-packages (from ipython->jupyter_dash) (0.6.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests->jupyter_dash) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.12/site-packages (from requests->jupyter_dash) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.12/site-packages (from requests->jupyter_dash) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.12/site-packages (from requests->jupyter_dash) (2024.12.14)
# Requirement already satisfied: six>=1.7.0 in /opt/conda/lib/python3.12/site-packages (from retrying->jupyter_dash) (1.17.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /opt/conda/lib/python3.12/site-packages (from jedi>=0.16->ipython->jupyter_dash) (0.8.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.12/site-packages (from Jinja2>=3.1.2->flask->jupyter_dash) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.12/site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter_dash) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in /opt/conda/lib/python3.12/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter_dash) (4.3.6)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/lib/python3.12/site-packages (from pexpect>4.3->ipython->jupyter_dash) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython->jupyter_dash) (0.2.13)
# Requirement already satisfied: brotli in /opt/conda/lib/python3.12/site-packages (from flask-compress->dash->jupyter_dash) (1.1.0)
# Requirement already satisfied: zstandard in /opt/conda/lib/python3.12/site-packages (from flask-compress->dash->jupyter_dash) (0.23.0)
# Requirement already satisfied: tenacity>=6.2.0 in /opt/conda/lib/python3.12/site-packages (from plotly->dash->jupyter_dash) (9.0.0)
# Requirement already satisfied: executing>=1.2.0 in /opt/conda/lib/python3.12/site-packages (from stack_data->ipython->jupyter_dash) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/conda/lib/python3.12/site-packages (from stack_data->ipython->jupyter_dash) (3.0.0)
# Requirement already satisfied: pure_eval in /opt/conda/lib/python3.12/site-packages (from stack_data->ipython->jupyter_dash) (0.2.3)
# Downloading jupyter_dash-0.4.2-py3-none-any.whl (23 kB)
# Downloading ansi2html-1.9.2-py3-none-any.whl (17 kB)
# Downloading retrying-1.3.4-py3-none-any.whl (11 kB)
# Installing collected packages: retrying, ansi2html, jupyter_dash
# Successfully installed ansi2html-1.9.2 jupyter_dash-0.4.2 retrying-1.3.4
# Requirement already satisfied: plotly in /opt/conda/lib/python3.12/site-packages (5.24.1)
# Collecting plotly
#   Downloading plotly-6.0.0-py3-none-any.whl.metadata (5.6 kB)
# Collecting narwhals>=1.15.1 (from plotly)
#   Downloading narwhals-1.26.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.12/site-packages (from plotly) (24.2)
# Downloading plotly-6.0.0-py3-none-any.whl (14.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.8/14.8 MB 177.8 MB/s eta 0:00:00
# Downloading narwhals-1.26.0-py3-none-any.whl (306 kB)
# Installing collected packages: narwhals, plotly
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.24.1
#     Uninstalling plotly-5.24.1:
#       Successfully uninstalled plotly-5.24.1
# Successfully installed narwhals-1.26.0 plotly-6.0.0

# %%
import pandas as pd
import dash
import dash_html_components as html
import dash_core_components as dcc
from dash.dependencies import Input, Output
from jupyter_dash import JupyterDash
import plotly.graph_objects as go
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 2
#       1 import pandas as pd
# ----> 2 import dash
#       3 import dash_html_components as html
#       4 import dash_core_components as dcc
#
# File /opt/conda/lib/python3.12/site-packages/dash/__init__.py:5
#       1 # pylint: disable=C0413
#       2 # __plotly_dash is for the "make sure you don't have a dash.py" check
#       3 # must come before any other imports.
#       4 __plotly_dash = True
# ----> 5 from .dash import Dash, no_update  # noqa: F401,E402
#       6 from . import dependencies  # noqa: F401,E402
#       7 from . import development  # noqa: F401,E402
#
# File /opt/conda/lib/python3.12/site-packages/dash/dash.py:22
#      20 import flask
#      21 from flask_compress import Compress
# ---> 22 from werkzeug.debug.tbtools import get_current_traceback
#      23 from pkg_resources import get_distribution, parse_version
#      25 import plotly
#
# ImportError: cannot import name 'get_current_traceback' from 'werkzeug.debug.tbtools' (/opt/conda/lib/python3.12/site-packages/werkzeug/debug/tbtools.py)

# %%
# !pip install --upgrade werkzeug
# Out:
# Requirement already satisfied: werkzeug in /opt/conda/lib/python3.12/site-packages (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/lib/python3.12/site-packages (from werkzeug) (3.0.2)

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /opt/conda/lib/python3.12/site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in /opt/conda/lib/python3.12/site-packages (from pandas) (2.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.12/site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.12/site-packages (from pandas) (2025.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd

# %%
import pandas as pd
import dash
import dash_html_components as html
import dash_core_components as dcc
from dash.dependencies import Input, Output
from jupyter_dash import JupyterDash
import plotly.graph_objects as go
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 2
#       1 import pandas as pd
# ----> 2 import dash
#       3 import dash_html_components as html
#       4 import dash_core_components as dcc
#
# File /opt/conda/lib/python3.12/site-packages/dash/__init__.py:5
#       1 # pylint: disable=C0413
#       2 # __plotly_dash is for the "make sure you don't have a dash.py" check
#       3 # must come before any other imports.
#       4 __plotly_dash = True
# ----> 5 from .dash import Dash, no_update  # noqa: F401,E402
#       6 from . import dependencies  # noqa: F401,E402
#       7 from . import development  # noqa: F401,E402
#
# File /opt/conda/lib/python3.12/site-packages/dash/dash.py:22
#      20 import flask
#      21 from flask_compress import Compress
# ---> 22 from werkzeug.debug.tbtools import get_current_traceback
#      23 from pkg_resources import get_distribution, parse_version
#      25 import plotly
#
# ImportError: cannot import name 'get_current_traceback' from 'werkzeug.debug.tbtools' (/opt/conda/lib/python3.12/site-packages/werkzeug/debug/tbtools.py)

# %%
# !pip install --upgrade werkzeug
# Out:
# Requirement already satisfied: werkzeug in /opt/conda/lib/python3.12/site-packages (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/lib/python3.12/site-packages (from werkzeug) (3.0.2)

# %%
import pandas as pd
import dash
import dash_html_components as html
import dash_core_components as dcc
from dash.dependencies import Input, Output
from jupyter_dash import JupyterDash
import plotly.graph_objects as go
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[8], line 2
#       1 import pandas as pd
# ----> 2 import dash
#       3 import dash_html_components as html
#       4 import dash_core_components as dcc
#
# File /opt/conda/lib/python3.12/site-packages/dash/__init__.py:5
#       1 # pylint: disable=C0413
#       2 # __plotly_dash is for the "make sure you don't have a dash.py" check
#       3 # must come before any other imports.
#       4 __plotly_dash = True
# ----> 5 from .dash import Dash, no_update  # noqa: F401,E402
#       6 from . import dependencies  # noqa: F401,E402
#       7 from . import development  # noqa: F401,E402
#
# File /opt/conda/lib/python3.12/site-packages/dash/dash.py:22
#      20 import flask
#      21 from flask_compress import Compress
# ---> 22 from werkzeug.debug.tbtools import get_current_traceback
#      23 from pkg_resources import get_distribution, parse_version
#      25 import plotly
#
# ImportError: cannot import name 'get_current_traceback' from 'werkzeug.debug.tbtools' (/opt/conda/lib/python3.12/site-packages/werkzeug/debug/tbtools.py)

# %%
# !pip install dash
# Out:
# Requirement already satisfied: dash in /opt/conda/lib/python3.12/site-packages (1.19.0)
# Requirement already satisfied: Flask>=1.0.4 in /opt/conda/lib/python3.12/site-packages (from dash) (3.1.0)
# Requirement already satisfied: flask-compress in /opt/conda/lib/python3.12/site-packages (from dash) (1.17)
# Requirement already satisfied: plotly in /opt/conda/lib/python3.12/site-packages (from dash) (6.0.0)
# Requirement already satisfied: dash_renderer==1.9.0 in /opt/conda/lib/python3.12/site-packages (from dash) (1.9.0)
# Requirement already satisfied: dash-core-components==1.15.0 in /opt/conda/lib/python3.12/site-packages (from dash) (1.15.0)
# Requirement already satisfied: dash-html-components==1.1.2 in /opt/conda/lib/python3.12/site-packages (from dash) (1.1.2)
# Requirement already satisfied: dash-table==4.11.2 in /opt/conda/lib/python3.12/site-packages (from dash) (4.11.2)
# Requirement already satisfied: future in /opt/conda/lib/python3.12/site-packages (from dash) (1.0.0)
# Requirement already satisfied: Werkzeug>=3.1 in /opt/conda/lib/python3.12/site-packages (from Flask>=1.0.4->dash) (3.1.3)
# Requirement already satisfied: Jinja2>=3.1.2 in /opt/conda/lib/python3.12/site-packages (from Flask>=1.0.4->dash) (3.1.5)
# Requirement already satisfied: itsdangerous>=2.2 in /opt/conda/lib/python3.12/site-packages (from Flask>=1.0.4->dash) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in /opt/conda/lib/python3.12/site-packages (from Flask>=1.0.4->dash) (8.1.8)
# Requirement already satisfied: blinker>=1.9 in /opt/conda/lib/python3.12/site-packages (from Flask>=1.0.4->dash) (1.9.0)
# Requirement already satisfied: brotli in /opt/conda/lib/python3.12/site-packages (from flask-compress->dash) (1.1.0)
# Requirement already satisfied: zstandard in /opt/conda/lib/python3.12/site-packages (from flask-compress->dash) (0.23.0)
# Requirement already satisfied: narwhals>=1.15.1 in /opt/conda/lib/python3.12/site-packages (from plotly->dash) (1.26.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.12/site-packages (from plotly->dash) (24.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.12/site-packages (from Jinja2>=3.1.2->Flask>=1.0.4->dash) (3.0.2)

# %%
import dash
from dash import dcc, html
from dash.dependencies import Input, Output
import plotly.express as px
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 import dash
#       2 from dash import dcc, html
#       3 from dash.dependencies import Input, Output
#
# File /opt/conda/lib/python3.12/site-packages/dash/__init__.py:5
#       1 # pylint: disable=C0413
#       2 # __plotly_dash is for the "make sure you don't have a dash.py" check
#       3 # must come before any other imports.
#       4 __plotly_dash = True
# ----> 5 from .dash import Dash, no_update  # noqa: F401,E402
#       6 from . import dependencies  # noqa: F401,E402
#       7 from . import development  # noqa: F401,E402
#
# File /opt/conda/lib/python3.12/site-packages/dash/dash.py:22
#      20 import flask
#      21 from flask_compress import Compress
# ---> 22 from werkzeug.debug.tbtools import get_current_traceback
#      23 from pkg_resources import get_distribution, parse_version
#      25 import plotly
#
# ImportError: cannot import name 'get_current_traceback' from 'werkzeug.debug.tbtools' (/opt/conda/lib/python3.12/site-packages/werkzeug/debug/tbtools.py)

# %%
spacex_df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_dash.csv")

# %%
# !pip install pandas dash
# Out:
# Requirement already satisfied: pandas in /opt/conda/lib/python3.12/site-packages (2.2.3)
# Requirement already satisfied: dash in /opt/conda/lib/python3.12/site-packages (1.19.0)
# Requirement already satisfied: numpy>=1.26.0 in /opt/conda/lib/python3.12/site-packages (from pandas) (2.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.12/site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.12/site-packages (from pandas) (2025.1)
# Requirement already satisfied: Flask>=1.0.4 in /opt/conda/lib/python3.12/site-packages (from dash) (3.1.0)
# Requirement already satisfied: flask-compress in /opt/conda/lib/python3.12/site-packages (from dash) (1.17)
# Requirement already satisfied: plotly in /opt/conda/lib/python3.12/site-packages (from dash) (6.0.0)
# Requirement already satisfied: dash_renderer==1.9.0 in /opt/conda/lib/python3.12/site-packages (from dash) (1.9.0)
# Requirement already satisfied: dash-core-components==1.15.0 in /opt/conda/lib/python3.12/site-packages (from dash) (1.15.0)
# Requirement already satisfied: dash-html-components==1.1.2 in /opt/conda/lib/python3.12/site-packages (from dash) (1.1.2)
# Requirement already satisfied: dash-table==4.11.2 in /opt/conda/lib/python3.12/site-packages (from dash) (4.11.2)
# Requirement already satisfied: future in /opt/conda/lib/python3.12/site-packages (from dash) (1.0.0)
# Requirement already satisfied: Werkzeug>=3.1 in /opt/conda/lib/python3.12/site-packages (from Flask>=1.0.4->dash) (3.1.3)
# Requirement already satisfied: Jinja2>=3.1.2 in /opt/conda/lib/python3.12/site-packages (from Flask>=1.0.4->dash) (3.1.5)
# Requirement already satisfied: itsdangerous>=2.2 in /opt/conda/lib/python3.12/site-packages (from Flask>=1.0.4->dash) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in /opt/conda/lib/python3.12/site-packages (from Flask>=1.0.4->dash) (8.1.8)
# Requirement already satisfied: blinker>=1.9 in /opt/conda/lib/python3.12/site-packages (from Flask>=1.0.4->dash) (1.9.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: brotli in /opt/conda/lib/python3.12/site-packages (from flask-compress->dash) (1.1.0)
# Requirement already satisfied: zstandard in /opt/conda/lib/python3.12/site-packages (from flask-compress->dash) (0.23.0)
# Requirement already satisfied: narwhals>=1.15.1 in /opt/conda/lib/python3.12/site-packages (from plotly->dash) (1.26.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.12/site-packages (from plotly->dash) (24.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.12/site-packages (from Jinja2>=3.1.2->Flask>=1.0.4->dash) (3.0.2)

# %%
df = pd.read_csv('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_dash.csv')

# %%
app.layout = html.Div([
    dcc.Dropdown(
        id='dropdown',
        options=[{'label': i, 'value': i} for i in df['column_name'].unique()],
        value='default_value'
    ),
    dcc.Graph(id='graph')
])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 app.layout = html.Div([
#       2     dcc.Dropdown(
#       3         id='dropdown',
#       4         options=[{'label': i, 'value': i} for i in df['column_name'].unique()],
#       5         value='default_value'
#       6     ),
#       7     dcc.Graph(id='graph')
#       8 ])
#
# NameError: name 'html' is not defined

# %%
from dash import dcc, html
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from dash import dcc, html
#
# ModuleNotFoundError: No module named 'dash'

# %%
# !pip install dash
# Out:
# Collecting dash
#   Downloading dash-2.18.2-py3-none-any.whl.metadata (10 kB)
# Collecting Flask<3.1,>=1.0.4 (from dash)
#   Downloading flask-3.0.3-py3-none-any.whl.metadata (3.2 kB)
# Collecting Werkzeug<3.1 (from dash)
#   Downloading werkzeug-3.0.6-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: plotly>=5.0.0 in /opt/conda/lib/python3.12/site-packages (from dash) (5.24.1)
# Collecting dash-html-components==2.0.0 (from dash)
#   Downloading dash_html_components-2.0.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting dash-core-components==2.0.0 (from dash)
#   Downloading dash_core_components-2.0.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting dash-table==5.0.0 (from dash)
#   Downloading dash_table-5.0.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: importlib-metadata in /opt/conda/lib/python3.12/site-packages (from dash) (8.6.1)
# Requirement already satisfied: typing-extensions>=4.1.1 in /opt/conda/lib/python3.12/site-packages (from dash) (4.12.2)
# Requirement already satisfied: requests in /opt/conda/lib/python3.12/site-packages (from dash) (2.32.3)
# Collecting retrying (from dash)
#   Downloading retrying-1.3.4-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: nest-asyncio in /opt/conda/lib/python3.12/site-packages (from dash) (1.6.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.12/site-packages (from dash) (75.8.0)
# Requirement already satisfied: Jinja2>=3.1.2 in /opt/conda/lib/python3.12/site-packages (from Flask<3.1,>=1.0.4->dash) (3.1.5)
# Collecting itsdangerous>=2.1.2 (from Flask<3.1,>=1.0.4->dash)
#   Downloading itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting click>=8.1.3 (from Flask<3.1,>=1.0.4->dash)
#   Downloading click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: blinker>=1.6.2 in /opt/conda/lib/python3.12/site-packages (from Flask<3.1,>=1.0.4->dash) (1.9.0)
# Requirement already satisfied: tenacity>=6.2.0 in /opt/conda/lib/python3.12/site-packages (from plotly>=5.0.0->dash) (9.0.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.12/site-packages (from plotly>=5.0.0->dash) (24.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/lib/python3.12/site-packages (from Werkzeug<3.1->dash) (3.0.2)
# Requirement already satisfied: zipp>=3.20 in /opt/conda/lib/python3.12/site-packages (from importlib-metadata->dash) (3.21.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests->dash) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.12/site-packages (from requests->dash) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.12/site-packages (from requests->dash) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.12/site-packages (from requests->dash) (2024.12.14)
# Requirement already satisfied: six>=1.7.0 in /opt/conda/lib/python3.12/site-packages (from retrying->dash) (1.17.0)
# Downloading dash-2.18.2-py3-none-any.whl (7.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 110.9 MB/s eta 0:00:00
# Downloading dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Downloading dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Downloading dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# Downloading flask-3.0.3-py3-none-any.whl (101 kB)
# Downloading werkzeug-3.0.6-py3-none-any.whl (227 kB)
# Downloading retrying-1.3.4-py3-none-any.whl (11 kB)
# Downloading click-8.1.8-py3-none-any.whl (98 kB)
# Downloading itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Installing collected packages: dash-table, dash-html-components, dash-core-components, Werkzeug, retrying, itsdangerous, click, Flask, dash
# Successfully installed Flask-3.0.3 Werkzeug-3.0.6 click-8.1.8 dash-2.18.2 dash-core-components-2.0.0 dash-html-components-2.0.0 dash-table-5.0.0 itsdangerous-2.2.0 retrying-1.3.4

# %%
from dash import dcc, html

# %%
app.layout = html.Div([
    dcc.Dropdown(
        id='dropdown',
        options=[{'label': i, 'value': i} for i in df['column_name'].unique()],
        value='default_value'
    ),
    dcc.Graph(id='graph')
# Out:
#   Cell In[4], line 7
#     dcc.Graph(id='graph')
#                          ^
# SyntaxError: incomplete input

# %%
@app.callback(
    Output('graph', 'figure'),
    [Input('dropdown', 'value')]
)
def update_graph(selected_value):
    filtered_df = df[df['column_name'] == selected_value]
    fig = px.bar(filtered_df, x='x_column', y='y_column')
    return fig
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 @app.callback(
#       2     Output('graph', 'figure'),
#       3     [Input('dropdown', 'value')]
#       4 )
#       5 def update_graph(selected_value):
#       6     filtered_df = df[df['column_name'] == selected_value]
#       7     fig = px.bar(filtered_df, x='x_column', y='y_column')
#
# NameError: name 'app' is not defined

# %%
# !pip install -r requirements.txt
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'

# %%
# !ls
# Out:
#  DASHBOARD.ipynb   WranglingnotebookSF.ipynb
#  Untitled.ipynb   'labs-jupyter-spacex-Data wrangling.ipynb'

# %%
# !pip install -r /path/to/requirements.txt
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: '/path/to/requirements.txt'

# %%
# !chmod 644 requirements.txt
# Out:
# chmod: cannot access 'requirements.txt': No such file or directory

# %%
with open('requirements.txt', 'w') as f:
    f.write('pandas\n')
    f.write('dash\n')
    f.write('plotly\n')

# %%
# !pip install -r requirements.txt
# Out:
# Collecting pandas (from -r requirements.txt (line 1))
#   Downloading pandas-2.2.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (89 kB)
# Requirement already satisfied: dash in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 2)) (2.18.2)
# Requirement already satisfied: plotly in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 3)) (5.24.1)
# Collecting numpy>=1.26.0 (from pandas->-r requirements.txt (line 1))
#   Downloading numpy-2.2.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.12/site-packages (from pandas->-r requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.12/site-packages (from pandas->-r requirements.txt (line 1)) (2024.2)
# Collecting tzdata>=2022.7 (from pandas->-r requirements.txt (line 1))
#   Downloading tzdata-2025.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in /opt/conda/lib/python3.12/site-packages (from dash->-r requirements.txt (line 2)) (3.0.3)
# Requirement already satisfied: Werkzeug<3.1 in /opt/conda/lib/python3.12/site-packages (from dash->-r requirements.txt (line 2)) (3.0.6)
# Requirement already satisfied: dash-html-components==2.0.0 in /opt/conda/lib/python3.12/site-packages (from dash->-r requirements.txt (line 2)) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in /opt/conda/lib/python3.12/site-packages (from dash->-r requirements.txt (line 2)) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in /opt/conda/lib/python3.12/site-packages (from dash->-r requirements.txt (line 2)) (5.0.0)
# Requirement already satisfied: importlib-metadata in /opt/conda/lib/python3.12/site-packages (from dash->-r requirements.txt (line 2)) (8.6.1)
# Requirement already satisfied: typing-extensions>=4.1.1 in /opt/conda/lib/python3.12/site-packages (from dash->-r requirements.txt (line 2)) (4.12.2)
# Requirement already satisfied: requests in /opt/conda/lib/python3.12/site-packages (from dash->-r requirements.txt (line 2)) (2.32.3)
# Requirement already satisfied: retrying in /opt/conda/lib/python3.12/site-packages (from dash->-r requirements.txt (line 2)) (1.3.4)
# Requirement already satisfied: nest-asyncio in /opt/conda/lib/python3.12/site-packages (from dash->-r requirements.txt (line 2)) (1.6.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.12/site-packages (from dash->-r requirements.txt (line 2)) (75.8.0)
# Requirement already satisfied: tenacity>=6.2.0 in /opt/conda/lib/python3.12/site-packages (from plotly->-r requirements.txt (line 3)) (9.0.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.12/site-packages (from plotly->-r requirements.txt (line 3)) (24.2)
# Requirement already satisfied: Jinja2>=3.1.2 in /opt/conda/lib/python3.12/site-packages (from Flask<3.1,>=1.0.4->dash->-r requirements.txt (line 2)) (3.1.5)
# Requirement already satisfied: itsdangerous>=2.1.2 in /opt/conda/lib/python3.12/site-packages (from Flask<3.1,>=1.0.4->dash->-r requirements.txt (line 2)) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in /opt/conda/lib/python3.12/site-packages (from Flask<3.1,>=1.0.4->dash->-r requirements.txt (line 2)) (8.1.8)
# Requirement already satisfied: blinker>=1.6.2 in /opt/conda/lib/python3.12/site-packages (from Flask<3.1,>=1.0.4->dash->-r requirements.txt (line 2)) (1.9.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 1)) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/lib/python3.12/site-packages (from Werkzeug<3.1->dash->-r requirements.txt (line 2)) (3.0.2)
# Requirement already satisfied: zipp>=3.20 in /opt/conda/lib/python3.12/site-packages (from importlib-metadata->dash->-r requirements.txt (line 2)) (3.21.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests->dash->-r requirements.txt (line 2)) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.12/site-packages (from requests->dash->-r requirements.txt (line 2)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.12/site-packages (from requests->dash->-r requirements.txt (line 2)) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.12/site-packages (from requests->dash->-r requirements.txt (line 2)) (2024.12.14)
# Downloading pandas-2.2.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.7/12.7 MB 165.8 MB/s eta 0:00:00
# Downloading numpy-2.2.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.1/16.1 MB 206.0 MB/s eta 0:00:00
# Downloading tzdata-2025.1-py2.py3-none-any.whl (346 kB)
# Installing collected packages: tzdata, numpy, pandas
# Successfully installed numpy-2.2.2 pandas-2.2.3 tzdata-2025.1

# %%
# !ls
# Out:
#  DASHBOARD.ipynb   WranglingnotebookSF.ipynb		       requirements.txt
#  Untitled.ipynb   'labs-jupyter-spacex-Data wrangling.ipynb'

# %%
from dash import dcc, html

# %%
app.layout = html.Div([
    dcc.Dropdown(
        id='dropdown',
        options=[{'label': i, 'value': i} for i in df['column_name'].unique()],
        value='default_value'
    ),
    dcc.Graph(id='graph')
# Out:
#   Cell In[14], line 7
#     dcc.Graph(id='graph')
#                          ^
# SyntaxError: incomplete input

# %%
@app.callback(
    Output('graph', 'figure'),
    [Input('dropdown', 'value')]
)
def update_graph(selected_value):
    filtered_df = df[df['column_name'] == selected_value]
    fig = px.bar(filtered_df, x='x_column', y='y_column')
    return fig
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 @app.callback(
#       2     Output('graph', 'figure'),
#       3     [Input('dropdown', 'value')]
#       4 )
#       5 def update_graph(selected_value):
#       6     filtered_df = df[df['column_name'] == selected_value]
#       7     fig = px.bar(filtered_df, x='x_column', y='y_column')
#
# NameError: name 'app' is not defined

# %%
app = dash.Dash(__name__)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 app = dash.Dash(__name__)
#
# NameError: name 'dash' is not defined

# %%
# !pip install dash
# Out:
# Requirement already satisfied: dash in /opt/conda/lib/python3.12/site-packages (2.18.2)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in /opt/conda/lib/python3.12/site-packages (from dash) (3.0.3)
# Requirement already satisfied: Werkzeug<3.1 in /opt/conda/lib/python3.12/site-packages (from dash) (3.0.6)
# Requirement already satisfied: plotly>=5.0.0 in /opt/conda/lib/python3.12/site-packages (from dash) (5.24.1)
# Requirement already satisfied: dash-html-components==2.0.0 in /opt/conda/lib/python3.12/site-packages (from dash) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in /opt/conda/lib/python3.12/site-packages (from dash) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in /opt/conda/lib/python3.12/site-packages (from dash) (5.0.0)
# Requirement already satisfied: importlib-metadata in /opt/conda/lib/python3.12/site-packages (from dash) (8.6.1)
# Requirement already satisfied: typing-extensions>=4.1.1 in /opt/conda/lib/python3.12/site-packages (from dash) (4.12.2)
# Requirement already satisfied: requests in /opt/conda/lib/python3.12/site-packages (from dash) (2.32.3)
# Requirement already satisfied: retrying in /opt/conda/lib/python3.12/site-packages (from dash) (1.3.4)
# Requirement already satisfied: nest-asyncio in /opt/conda/lib/python3.12/site-packages (from dash) (1.6.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.12/site-packages (from dash) (75.8.0)
# Requirement already satisfied: Jinja2>=3.1.2 in /opt/conda/lib/python3.12/site-packages (from Flask<3.1,>=1.0.4->dash) (3.1.5)
# Requirement already satisfied: itsdangerous>=2.1.2 in /opt/conda/lib/python3.12/site-packages (from Flask<3.1,>=1.0.4->dash) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in /opt/conda/lib/python3.12/site-packages (from Flask<3.1,>=1.0.4->dash) (8.1.8)
# Requirement already satisfied: blinker>=1.6.2 in /opt/conda/lib/python3.12/site-packages (from Flask<3.1,>=1.0.4->dash) (1.9.0)
# Requirement already satisfied: tenacity>=6.2.0 in /opt/conda/lib/python3.12/site-packages (from plotly>=5.0.0->dash) (9.0.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.12/site-packages (from plotly>=5.0.0->dash) (24.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/lib/python3.12/site-packages (from Werkzeug<3.1->dash) (3.0.2)
# Requirement already satisfied: zipp>=3.20 in /opt/conda/lib/python3.12/site-packages (from importlib-metadata->dash) (3.21.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests->dash) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.12/site-packages (from requests->dash) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.12/site-packages (from requests->dash) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.12/site-packages (from requests->dash) (2024.12.14)
# Requirement already satisfied: six>=1.7.0 in /opt/conda/lib/python3.12/site-packages (from retrying->dash) (1.17.0)

# %%
import dash
from dash import dcc, html

# %%
app = dash.Dash(__name__)

# %%
@app.callback(
    Output('graph', 'figure'),
    [Input('dropdown', 'value')]
)
def update_graph(selected_value):
    filtered_df = df[df['column_name'] == selected_value]
    fig = px.bar(filtered_df, x='x_column', y='y_column')
    return fig
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 2
#       1 @app.callback(
# ----> 2     Output('graph', 'figure'),
#       3     [Input('dropdown', 'value')]
#       4 )
#       5 def update_graph(selected_value):
#       6     filtered_df = df[df['column_name'] == selected_value]
#       7     fig = px.bar(filtered_df, x='x_column', y='y_column')
#
# NameError: name 'Output' is not defined

# %%
from dash.dependencies import Output, Input

# %%
@app.callback(
    Output('graph', 'figure'),
    [Input('dropdown', 'value')]
)
def update_graph(selected_value):
    # Your code to update the graph
    return figure
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 @app.callback(
#       2     Output('graph', 'figure'),
#       3     [Input('dropdown', 'value')]
#       4 )
#       5 def update_graph(selected_value):
#       6     # Your code to update the graph
#       7     return figure
#
# NameError: name 'app' is not defined

# %%
# Import required libraries
import pandas as pd
import dash
import dash_html_components as html
import dash_core_components as dcc
from dash.dependencies import Input, Output
import plotly.express as px
 
# Read the airline data into pandas dataframe
spacex_df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_dash.csv")
max_payload = spacex_df['Payload Mass (kg)'].max()
min_payload = spacex_df['Payload Mass (kg)'].min()
 
# Create a dash application
app = dash.Dash(__name__)
 
# Create an app layout
app.layout = html.Div(children=[
    html.H1('SpaceX Launch Records Dash',
            style={'textAlign': 'center', 'color': '#503D36','font-size': 40}),
 
    # TASK 1: Add a dropdown list to enable Launch Site selection
    dcc.Dropdown(
        id='site-dropdown',
        options=[
            {'label': 'All Sites', 'value': 'ALL'},
            {'label': 'CCAFS LC-40', 'value': 'CCAFS LC-40'},
            {'label': 'CCAFS SLC-40', 'value': 'CCAFS SLC-40'},
            {'label': 'KSC LC-39A', 'value': 'KSC LC-39A'},
            {'label': 'VAFB SLC-4E', 'value': 'VAFB SLC-4E'}
        ],
        value='ALL',
        placeholder="Place holder site here",
        searchable=True
    ),
    html.Br(),
 
    # TASK 2: Add a pie chart to show the total successful launches count for all sites
    html.Div(dcc.Graph(id='success-pie-chart')),
    html.Br(),
 
    html.P("Payload range (Kg):"),
    dcc.RangeSlider(
        id='payload-slider',
        min=0, 
        max=10000, 
        step=1000,
        marks={0: '0(Kg)',2500: '2500 (Kg)', 5000: '5000 (Kg)',7500: '7500 (Kg)', 10000: '10000 (Kg)'},
        value=[min_payload, max_payload]
    ),
 
     # TASK 4: Add a scatter chart to show the correlation between payload and launch success
     html.Div(dcc.Graph(id='success-payload-scatter-chart')),
    ])
 
# TASK 2:
# Add a callback function for `site-dropdown` as input, `success-pie-chart` as output
@app.callback(
    Output(component_id='success-pie-chart', component_property='figure'),
    Input(component_id='site-dropdown', component_property='value')
)
def get_pie_chart(entered_site):
    filtered_df = spacex_df
    if entered_site == 'ALL':
        fig = px.pie(filtered_df, values='class', 
                    names='Launch Site', 
                    title='Total Successful Launches by Site')
    else:
        filtered_df = spacex_df[spacex_df['Launch Site'] == entered_site]
        filtered_df = filtered_df.groupby(['Launch Site','class']).size().reset_index(name='class count')
        fig = px.pie(filtered_df, values='class count', 
                     names='class',
                     title=f'Total Sucessful Launches for Site {entered_site}')
    return fig
 
# TASK 4:
# Add a callback function for `site-dropdown` and `payload-slider` as inputs, `success-payload-scatter-chart` as output
@app.callback(
    Output(component_id='success-payload-scatter-chart', component_property='figure'),
    [Input(component_id='site-dropdown', component_property='value'), 
    Input(component_id="payload-slider", component_property="value")]
)
def get_scatter_chart(entered_site, payload_range):
    filtered_df = spacex_df[(spacex_df['Payload Mass (kg)']>= payload_range[0]) &
                            (spacex_df['Payload Mass (kg)']<= payload_range[1])]
    if entered_site == 'ALL':
        fig = px.scatter(filtered_df, x='Payload Mass (kg)', y='class',
                         color='Booster Version Category',
                         title='Payload vs. Success for All Sites')
    else:
        filtered_df = filtered_df[filtered_df['Launch Site']== entered_site]
        fig = px.scatter(filtered_df, x='Payload Mass (kg)', y='class',
                         color='Booster Version Category',
                         title=f'Payload vs. Success for site {entered_site}')
    return fig
 
# Run the app
if __name__ == '__main__':
    app.run_server()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Import required libraries
# ----> 2 import pandas as pd
#       3 import dash
#       4 import dash_html_components as html
#
# ModuleNotFoundError: No module named 'pandas'

# %%
# !pip install pandas dash
# Out:
# Collecting pandas
#   Downloading pandas-2.2.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (89 kB)
# Collecting dash
#   Downloading dash-2.18.2-py3-none-any.whl.metadata (10 kB)
# Collecting numpy>=1.26.0 (from pandas)
#   Downloading numpy-2.2.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.12/site-packages (from pandas) (2024.2)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2025.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting Flask<3.1,>=1.0.4 (from dash)
#   Downloading flask-3.0.3-py3-none-any.whl.metadata (3.2 kB)
# Collecting Werkzeug<3.1 (from dash)
#   Downloading werkzeug-3.0.6-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: plotly>=5.0.0 in /opt/conda/lib/python3.12/site-packages (from dash) (5.24.1)
# Collecting dash-html-components==2.0.0 (from dash)
#   Downloading dash_html_components-2.0.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting dash-core-components==2.0.0 (from dash)
#   Downloading dash_core_components-2.0.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting dash-table==5.0.0 (from dash)
#   Downloading dash_table-5.0.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: importlib-metadata in /opt/conda/lib/python3.12/site-packages (from dash) (8.6.1)
# Requirement already satisfied: typing-extensions>=4.1.1 in /opt/conda/lib/python3.12/site-packages (from dash) (4.12.2)
# Requirement already satisfied: requests in /opt/conda/lib/python3.12/site-packages (from dash) (2.32.3)
# Collecting retrying (from dash)
#   Downloading retrying-1.3.4-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: nest-asyncio in /opt/conda/lib/python3.12/site-packages (from dash) (1.6.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.12/site-packages (from dash) (75.8.0)
# Requirement already satisfied: Jinja2>=3.1.2 in /opt/conda/lib/python3.12/site-packages (from Flask<3.1,>=1.0.4->dash) (3.1.5)
# Collecting itsdangerous>=2.1.2 (from Flask<3.1,>=1.0.4->dash)
#   Downloading itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting click>=8.1.3 (from Flask<3.1,>=1.0.4->dash)
#   Downloading click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: blinker>=1.6.2 in /opt/conda/lib/python3.12/site-packages (from Flask<3.1,>=1.0.4->dash) (1.9.0)
# Requirement already satisfied: tenacity>=6.2.0 in /opt/conda/lib/python3.12/site-packages (from plotly>=5.0.0->dash) (9.0.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.12/site-packages (from plotly>=5.0.0->dash) (24.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/lib/python3.12/site-packages (from Werkzeug<3.1->dash) (3.0.2)
# Requirement already satisfied: zipp>=3.20 in /opt/conda/lib/python3.12/site-packages (from importlib-metadata->dash) (3.21.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests->dash) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.12/site-packages (from requests->dash) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.12/site-packages (from requests->dash) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.12/site-packages (from requests->dash) (2024.12.14)
# Downloading pandas-2.2.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.7/12.7 MB 168.9 MB/s eta 0:00:00
# Downloading dash-2.18.2-py3-none-any.whl (7.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 150.7 MB/s eta 0:00:00
# Downloading dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Downloading dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Downloading dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# Downloading flask-3.0.3-py3-none-any.whl (101 kB)
# Downloading numpy-2.2.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.1/16.1 MB 199.6 MB/s eta 0:00:00
# Downloading tzdata-2025.1-py2.py3-none-any.whl (346 kB)
# Downloading werkzeug-3.0.6-py3-none-any.whl (227 kB)
# Downloading retrying-1.3.4-py3-none-any.whl (11 kB)
# Downloading click-8.1.8-py3-none-any.whl (98 kB)
# Downloading itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Installing collected packages: dash-table, dash-html-components, dash-core-components, Werkzeug, tzdata, retrying, numpy, itsdangerous, click, pandas, Flask, dash
# Successfully installed Flask-3.0.3 Werkzeug-3.0.6 click-8.1.8 dash-2.18.2 dash-core-components-2.0.0 dash-html-components-2.0.0 dash-table-5.0.0 itsdangerous-2.2.0 numpy-2.2.3 pandas-2.2.3 retrying-1.3.4 tzdata-2025.1

# %%
# Import required libraries
import pandas as pd
import dash
import dash_html_components as html
import dash_core_components as dcc
from dash.dependencies import Input, Output
import plotly.express as px
 
# Read the airline data into pandas dataframe
spacex_df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_dash.csv")
max_payload = spacex_df['Payload Mass (kg)'].max()
min_payload = spacex_df['Payload Mass (kg)'].min()
 
# Create a dash application
app = dash.Dash(__name__)
 
# Create an app layout
app.layout = html.Div(children=[
    html.H1('SpaceX Launch Records Dash',
            style={'textAlign': 'center', 'color': '#503D36','font-size': 40}),
 
    # TASK 1: Add a dropdown list to enable Launch Site selection
    dcc.Dropdown(
        id='site-dropdown',
        options=[
            {'label': 'All Sites', 'value': 'ALL'},
            {'label': 'CCAFS LC-40', 'value': 'CCAFS LC-40'},
            {'label': 'CCAFS SLC-40', 'value': 'CCAFS SLC-40'},
            {'label': 'KSC LC-39A', 'value': 'KSC LC-39A'},
            {'label': 'VAFB SLC-4E', 'value': 'VAFB SLC-4E'}
        ],
        value='ALL',
        placeholder="Place holder site here",
        searchable=True
    ),
    html.Br(),
 
    # TASK 2: Add a pie chart to show the total successful launches count for all sites
    html.Div(dcc.Graph(id='success-pie-chart')),
    html.Br(),
 
    html.P("Payload range (Kg):"),
    dcc.RangeSlider(
        id='payload-slider',
        min=0, 
        max=10000, 
        step=1000,
        marks={0: '0(Kg)',2500: '2500 (Kg)', 5000: '5000 (Kg)',7500: '7500 (Kg)', 10000: '10000 (Kg)'},
        value=[min_payload, max_payload]
    ),
 
     # TASK 4: Add a scatter chart to show the correlation between payload and launch success
     html.Div(dcc.Graph(id='success-payload-scatter-chart')),
    ])
 
# TASK 2:
# Add a callback function for `site-dropdown` as input, `success-pie-chart` as output
@app.callback(
    Output(component_id='success-pie-chart', component_property='figure'),
    Input(component_id='site-dropdown', component_property='value')
)
def get_pie_chart(entered_site):
    filtered_df = spacex_df
    if entered_site == 'ALL':
        fig = px.pie(filtered_df, values='class', 
                    names='Launch Site', 
                    title='Total Successful Launches by Site')
    else:
        filtered_df = spacex_df[spacex_df['Launch Site'] == entered_site]
        filtered_df = filtered_df.groupby(['Launch Site','class']).size().reset_index(name='class count')
        fig = px.pie(filtered_df, values='class count', 
                     names='class',
                     title=f'Total Sucessful Launches for Site {entered_site}')
    return fig
 
# TASK 4:
# Add a callback function for `site-dropdown` and `payload-slider` as inputs, `success-payload-scatter-chart` as output
@app.callback(
    Output(component_id='success-payload-scatter-chart', component_property='figure'),
    [Input(component_id='site-dropdown', component_property='value'), 
    Input(component_id="payload-slider", component_property="value")]
)
def get_scatter_chart(entered_site, payload_range):
    filtered_df = spacex_df[(spacex_df['Payload Mass (kg)']>= payload_range[0]) &
                            (spacex_df['Payload Mass (kg)']<= payload_range[1])]
    if entered_site == 'ALL':
        fig = px.scatter(filtered_df, x='Payload Mass (kg)', y='class',
                         color='Booster Version Category',
                         title='Payload vs. Success for All Sites')
    else:
        filtered_df = filtered_df[filtered_df['Launch Site']== entered_site]
        fig = px.scatter(filtered_df, x='Payload Mass (kg)', y='class',
                         color='Booster Version Category',
                         title=f'Payload vs. Success for site {entered_site}')
    return fig
 
# Run the app
if __name__ == '__main__':
    app.run_server()
# Out:
# /tmp/ipykernel_328/702216620.py:4: UserWarning:
# The dash_html_components package is deprecated. Please replace
# `import dash_html_components as html` with `from dash import html`
#   import dash_html_components as html
# /tmp/ipykernel_328/702216620.py:5: UserWarning:
# The dash_core_components package is deprecated. Please replace
# `import dash_core_components as dcc` with `from dash import dcc`
#   import dash_core_components as dcc
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[5], line 2
#       1 if __name__ == '__main__':
# ----> 2     app.run_server(debug=True)
#
# File /opt/conda/lib/python3.12/site-packages/dash/dash.py:2287, in Dash.run_server(self, *args, **kwargs)
#    2277 """`run_server` is a deprecated alias of `run` and may be removed in a
#    2278 future version. We recommend using `app.run` instead.
#    2279
#    2280 See `app.run` for usage information.
#    2281 """
#    2282 warnings.warn(
#    2283     DeprecationWarning(
#    2284         "Dash.run_server is deprecated and will be removed in Dash 3.0"
#    2285     )
#    2286 )
# -> 2287 self.run(*args, **kwargs)
#
# File /opt/conda/lib/python3.12/site-packages/dash/dash.py:2098, in Dash.run(self, host, port, proxy, debug, jupyter_mode, jupyter_width, jupyter_height, jupyter_server_url, dev_tools_ui, dev_tools_props_check, dev_tools_serve_dev_bundles, dev_tools_hot_reload, dev_tools_hot_reload_interval, dev_tools_hot_reload_watch_interval, dev_tools_hot_reload_max_retry, dev_tools_silence_routes_logging, dev_tools_prune_errors, **flask_run_options)
#    2095 if debug is None:
#    2096     debug = get_combined_config("debug", None, False)
# -> 2098 debug = self.enable_dev_tools(
#    2099     debug,
#    2100     dev_tools_ui,
#    2101     dev_tools_props_check,
#    2102     dev_tools_serve_dev_bundles,
#    2103     dev_tools_hot_reload,
#    2104     dev_tools_hot_reload_interval,
#    2105     dev_tools_hot_reload_watch_interval,
#    2106     dev_tools_hot_reload_max_retry,
#    2107     dev_tools_silence_routes_logging,
#    2108     dev_tools_prune_errors,
#    2109 )
#    2111 # Evaluate the env variables at runtime
#    2113 host = os.getenv("HOST", host)
#
# File /opt/conda/lib/python3.12/site-packages/dash/dash.py:1868, in Dash.enable_dev_tools(self, debug, dev_tools_ui, dev_tools_props_check, dev_tools_serve_dev_bundles, dev_tools_hot_reload, dev_tools_hot_reload_interval, dev_tools_hot_reload_watch_interval, dev_tools_hot_reload_max_retry, dev_tools_silence_routes_logging, dev_tools_prune_errors)
#    1866 if debug:
#    1867     if jupyter_dash.active:
# -> 1868         jupyter_dash.configure_callback_exception_handling(
#    1869             self, dev_tools.prune_errors
#    1870         )
#    1871     elif dev_tools.prune_errors:
#    1872         secret = gen_salt(20)
#
# File /opt/conda/lib/python3.12/site-packages/dash/_jupyter.py:447, in JupyterDash.configure_callback_exception_handling(self, app, dev_tools_prune_errors)
#     444 def configure_callback_exception_handling(self, app, dev_tools_prune_errors):
#     445     """Install traceback handling for callbacks"""
# --> 447     @app.server.errorhandler(Exception)
#     448     def _wrap_errors(error):
#     449         # Compute number of stack frames to skip to get down to callback
#     450         skip = _get_skip(error) if dev_tools_prune_errors else 0
#     452         # Customized formatargvalues function we can place function parameters
#     453         # on separate lines
#
# File /opt/conda/lib/python3.12/site-packages/flask/sansio/scaffold.py:46, in setupmethod.<locals>.wrapper_func(self, *args, **kwargs)
#      45 def wrapper_func(self: Scaffold, *args: t.Any, **kwargs: t.Any) -> t.Any:
# ---> 46     self._check_setup_finished(f_name)
#      47     return f(self, *args, **kwargs)
#
# File /opt/conda/lib/python3.12/site-packages/flask/sansio/app.py:415, in App._check_setup_finished(self, f_name)
#     413 def _check_setup_finished(self, f_name: str) -> None:
#     414     if self._got_first_request:
# --> 415         raise AssertionError(
#     416             f"The setup method '{f_name}' can no longer be called"
#     417             " on the application. It has already handled its first"
#     418             " request, any changes will not be applied"
#     419             " consistently.\n"
#     420             "Make sure all imports, decorators, functions, etc."
#     421             " needed to set up the application are done before"
#     422             " running it."
#     423         )
#
# AssertionError: The setup method 'errorhandler' can no longer be called on the application. It has already handled its first request, any changes will not be applied consistently.
# Make sure all imports, decorators, functions, etc. needed to set up the application are done before running it.

# %%
# !pip install dash==1.19.0  

# !pip install jupyter_dash 

# !pip install --upgrade plotly

import pandas as pd 

import dash 

import dash_html_components as html 

import dash_core_components as dcc from dash.dependencies

 import Input, Output from jupyter_dash 

import JupyterDash 

import plotly.graph_objects as go  

import plotly.express as px
# Out:
#   Cell In[1], line 13
#     import dash_core_components as dcc from dash.dependencies
#                                        ^
# SyntaxError: invalid syntax

# %%
import dash_core_components as dcc
from dash.dependencies import Output, Input
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import dash_core_components as dcc
#       2 from dash.dependencies import Output, Input
#
# ModuleNotFoundError: No module named 'dash_core_components'

# %%
# !pip install dash
# Out:
# Collecting dash
#   Downloading dash-2.18.2-py3-none-any.whl.metadata (10 kB)
# Collecting Flask<3.1,>=1.0.4 (from dash)
#   Downloading flask-3.0.3-py3-none-any.whl.metadata (3.2 kB)
# Collecting Werkzeug<3.1 (from dash)
#   Downloading werkzeug-3.0.6-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: plotly>=5.0.0 in /opt/conda/lib/python3.12/site-packages (from dash) (5.24.1)
# Collecting dash-html-components==2.0.0 (from dash)
#   Downloading dash_html_components-2.0.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting dash-core-components==2.0.0 (from dash)
#   Downloading dash_core_components-2.0.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting dash-table==5.0.0 (from dash)
#   Downloading dash_table-5.0.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: importlib-metadata in /opt/conda/lib/python3.12/site-packages (from dash) (8.6.1)
# Requirement already satisfied: typing-extensions>=4.1.1 in /opt/conda/lib/python3.12/site-packages (from dash) (4.12.2)
# Requirement already satisfied: requests in /opt/conda/lib/python3.12/site-packages (from dash) (2.32.3)
# Collecting retrying (from dash)
#   Downloading retrying-1.3.4-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: nest-asyncio in /opt/conda/lib/python3.12/site-packages (from dash) (1.6.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.12/site-packages (from dash) (75.8.0)
# Requirement already satisfied: Jinja2>=3.1.2 in /opt/conda/lib/python3.12/site-packages (from Flask<3.1,>=1.0.4->dash) (3.1.5)
# Collecting itsdangerous>=2.1.2 (from Flask<3.1,>=1.0.4->dash)
#   Downloading itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting click>=8.1.3 (from Flask<3.1,>=1.0.4->dash)
#   Downloading click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: blinker>=1.6.2 in /opt/conda/lib/python3.12/site-packages (from Flask<3.1,>=1.0.4->dash) (1.9.0)
# Requirement already satisfied: tenacity>=6.2.0 in /opt/conda/lib/python3.12/site-packages (from plotly>=5.0.0->dash) (9.0.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.12/site-packages (from plotly>=5.0.0->dash) (24.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/lib/python3.12/site-packages (from Werkzeug<3.1->dash) (3.0.2)
# Requirement already satisfied: zipp>=3.20 in /opt/conda/lib/python3.12/site-packages (from importlib-metadata->dash) (3.21.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests->dash) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.12/site-packages (from requests->dash) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.12/site-packages (from requests->dash) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.12/site-packages (from requests->dash) (2024.12.14)
# Requirement already satisfied: six>=1.7.0 in /opt/conda/lib/python3.12/site-packages (from retrying->dash) (1.17.0)
# Downloading dash-2.18.2-py3-none-any.whl (7.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 108.0 MB/s eta 0:00:00
# Downloading dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Downloading dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Downloading dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# Downloading flask-3.0.3-py3-none-any.whl (101 kB)
# Downloading werkzeug-3.0.6-py3-none-any.whl (227 kB)
# Downloading retrying-1.3.4-py3-none-any.whl (11 kB)
# Downloading click-8.1.8-py3-none-any.whl (98 kB)
# Downloading itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Installing collected packages: dash-table, dash-html-components, dash-core-components, Werkzeug, retrying, itsdangerous, click, Flask, dash
# Successfully installed Flask-3.0.3 Werkzeug-3.0.6 click-8.1.8 dash-2.18.2 dash-core-components-2.0.0 dash-html-components-2.0.0 dash-table-5.0.0 itsdangerous-2.2.0 retrying-1.3.4

# %%
# !pip show dash
# Out:
# Name: dash
# Version: 2.18.2
# Summary: A Python framework for building reactive web-apps. Developed by Plotly.
# Home-page: https://plotly.com/dash
# Author: Chris Parmer
# Author-email: chris@plotly.com
# License: MIT
# Location: /opt/conda/lib/python3.12/site-packages
# Requires: dash-core-components, dash-html-components, dash-table, Flask, importlib-metadata, nest-asyncio, plotly, requests, retrying, setuptools, typing-extensions, Werkzeug
# Required-by:

# %%
import pandas as pd 

import dash 

import dash_html_components as html 

import dash_core_components as dcc from dash.dependencies

 import Input, Output from jupyter_dash 

import JupyterDash 

import plotly.graph_objects as go  

import plotly.express as px
# Out:
#   Cell In[5], line 7
#     import dash_core_components as dcc from dash.dependencies
#                                        ^
# SyntaxError: invalid syntax

# %%
# !pip install dash==1.19.0  

# !pip install jupyter_dash 

# !pip install --upgrade plotly


import pandas as pd
import dash
import dash_html_components as html
import dash_core_components as dcc
from dash.dependencies import Input, Output
from jupyter_dash import JupyterDash
import plotly.graph_objects as go

spacex_df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_dash.csv")
max_payload = spacex_df['Payload Mass (kg)'].max()
min_payload = spacex_df['Payload Mass (kg)'].min()

# Create a dash application
app = JupyterDash(__name__)

# Create an app layout
app.layout = html.Div(children=[
    html.H1('SpaceX Launch Records Dash',
            style={'textAlign': 'center', 'color': '#503D36','font-size': 40}),
 
    # TASK 1: Add a dropdown list to enable Launch Site selection
    dcc.Dropdown(
        id='site-dropdown',
        options=[
            {'label': 'All Sites', 'value': 'ALL'},
            {'label': 'CCAFS LC-40', 'value': 'CCAFS LC-40'},
            {'label': 'CCAFS SLC-40', 'value': 'CCAFS SLC-40'},
            {'label': 'KSC LC-39A', 'value': 'KSC LC-39A'},
            {'label': 'VAFB SLC-4E', 'value': 'VAFB SLC-4E'}
        ],
        value='ALL',
        placeholder="Place holder site here",
        searchable=True
    ),
    html.Br(),
 
    # TASK 2: Add a pie chart to show the total successful launches count for all sites
    html.Div(dcc.Graph(id='success-pie-chart')),
    html.Br(),
 
    html.P("Payload range (Kg):"),
    dcc.RangeSlider(
        id='payload-slider',
        min=0, 
        max=10000, 
        step=1000,
        marks={0: '0(Kg)',2500: '2500 (Kg)', 5000: '5000 (Kg)',7500: '7500 (Kg)', 10000: '10000 (Kg)'},
        value=[min_payload, max_payload]
    ),
 
     # TASK 4: Add a scatter chart to show the correlation between payload and launch success
     html.Div(dcc.Graph(id='success-payload-scatter-chart')),
    ])
 

# TASK 2:
@app.callback(
    Output(component_id='success-pie-chart', component_property='figure'),
    Input(component_id='site-dropdown', component_property='value')
)
def get_pie_chart(entered_site):
    filtered_df = spacex_df
    if entered_site == 'ALL':
        fig = px.pie(filtered_df, values='class', 
                    names='Launch Site', 
                    title='Total Successful Launches by Site')
    else:
        filtered_df = spacex_df[spacex_df['Launch Site'] == entered_site]
        filtered_df = filtered_df.groupby(['Launch Site','class']).size().reset_index(name='class count')
        fig = px.pie(filtered_df, values='class count', 
                     names='class',
                     title=f'Total Sucessful Launches for Site {entered_site}')
    return fig

# TASK 4:
@app.callback(
    Output(component_id='success-payload-scatter-chart', component_property='figure'),
    [Input(component_id='site-dropdown', component_property='value'), 
    Input(component_id="payload-slider", component_property="value")]
)
def get_scatter_chart(entered_site, payload_range):
    filtered_df = spacex_df[(spacex_df['Payload Mass (kg)']>= payload_range[0]) &
                            (spacex_df['Payload Mass (kg)']<= payload_range[1])]
    if entered_site == 'ALL':
        fig = px.scatter(filtered_df, x='Payload Mass (kg)', y='class',
                         color='Booster Version Category',
                         title='Payload vs. Success for All Sites')
    else:
        filtered_df = filtered_df[filtered_df['Launch Site']== entered_site]
        fig = px.scatter(filtered_df, x='Payload Mass (kg)', y='class',
                         color='Booster Version Category',
                         title=f'Payload vs. Success for site {entered_site}')
    return fig

# Run the app
if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
# Collecting dash==1.19.0
#   Downloading dash-1.19.0.tar.gz (75 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: Flask>=1.0.4 in /opt/conda/lib/python3.12/site-packages (from dash==1.19.0) (3.0.3)
# Collecting flask-compress (from dash==1.19.0)
#   Downloading Flask_Compress-1.17-py3-none-any.whl.metadata (8.8 kB)
# Requirement already satisfied: plotly in /opt/conda/lib/python3.12/site-packages (from dash==1.19.0) (5.24.1)
# Collecting dash_renderer==1.9.0 (from dash==1.19.0)
#   Downloading dash_renderer-1.9.0.tar.gz (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 30.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting dash-core-components==1.15.0 (from dash==1.19.0)
#   Downloading dash_core_components-1.15.0.tar.gz (3.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 69.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting dash-html-components==1.1.2 (from dash==1.19.0)
#   Downloading dash_html_components-1.1.2.tar.gz (188 kB)
#   Preparing metadata (setup.py) ... done
# Collecting dash-table==4.11.2 (from dash==1.19.0)
#   Downloading dash_table-4.11.2.tar.gz (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 82.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting future (from dash==1.19.0)
#   Downloading future-1.0.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: Werkzeug>=3.0.0 in /opt/conda/lib/python3.12/site-packages (from Flask>=1.0.4->dash==1.19.0) (3.0.6)
# Requirement already satisfied: Jinja2>=3.1.2 in /opt/conda/lib/python3.12/site-packages (from Flask>=1.0.4->dash==1.19.0) (3.1.5)
# Requirement already satisfied: itsdangerous>=2.1.2 in /opt/conda/lib/python3.12/site-packages (from Flask>=1.0.4->dash==1.19.0) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in /opt/conda/lib/python3.12/site-packages (from Flask>=1.0.4->dash==1.19.0) (8.1.8)
# Requirement already satisfied: blinker>=1.6.2 in /opt/conda/lib/python3.12/site-packages (from Flask>=1.0.4->dash==1.19.0) (1.9.0)
# Requirement already satisfied: brotli in /opt/conda/lib/python3.12/site-packages (from flask-compress->dash==1.19.0) (1.1.0)
# Requirement already satisfied: zstandard in /opt/conda/lib/python3.12/site-packages (from flask-compress->dash==1.19.0) (0.23.0)
# Requirement already satisfied: tenacity>=6.2.0 in /opt/conda/lib/python3.12/site-packages (from plotly->dash==1.19.0) (9.0.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.12/site-packages (from plotly->dash==1.19.0) (24.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.12/site-packages (from Jinja2>=3.1.2->Flask>=1.0.4->dash==1.19.0) (3.0.2)
# Downloading Flask_Compress-1.17-py3-none-any.whl (8.7 kB)
# Downloading future-1.0.0-py3-none-any.whl (491 kB)
# Building wheels for collected packages: dash, dash-core-components, dash-html-components, dash_renderer, dash-table
#   Building wheel for dash (setup.py) ... one
#   Created wheel for dash: filename=dash-1.19.0-py3-none-any.whl size=84056 sha256=4e47b796c9d07d2fd8051e03117286367cecdd58b3eeab6e338bbb8e43eddcbb
#   Stored in directory: /home/jupyterlab/.cache/pip/wheels/1e/44/a1/f967f9b725ad97e257143699ff444863de3a55a66360f7fe46
#   Building wheel for dash-core-components (setup.py) ... one
#   Created wheel for dash-core-components: filename=dash_core_components-1.15.0-py3-none-any.whl size=3527013 sha256=20de10c0ff19c58d31995492f06bad7d84e567d267fe958a6dbe1b9458fff876
#   Stored in directory: /home/jupyterlab/.cache/pip/wheels/6a/a1/bd/ecc107b05a332f46dbdab9f3325fed6ce94360ed5f7a255794
#   Building wheel for dash-html-components (setup.py) ... one
#   Created wheel for dash-html-components: filename=dash_html_components-1.1.2-py3-none-any.whl size=427860 sha256=5e16d6e5c5f7abab9a5f0a457608d4b0a97d83ae61668987c0a7c0bf64403d24
#   Stored in directory: /home/jupyterlab/.cache/pip/wheels/c9/81/b4/150da76adfebe6b5e173950a50648ba52c8d4ce3396aede4c8
#   Building wheel for dash_renderer (setup.py) ... one
#   Created wheel for dash_renderer: filename=dash_renderer-1.9.0-py3-none-any.whl size=1014867 sha256=484d8bdd91256c8d0a134189a6763882542a5f8c9fc10d527e92292df4920b92
#   Stored in directory: /home/jupyterlab/.cache/pip/wheels/37/ed/88/9e5f26b7a4161de4603c5e913af0ec1b6a345840478cb2fd69
#   Building wheel for dash-table (setup.py) ... one
#   Created wheel for dash-table: filename=dash_table-4.11.2-py3-none-any.whl size=1839864 sha256=ae84ff7b1bc082ea4a70fbc9e6cac6f1ab2b1c16358deb9ac3caf6c0f7a859b6
#   Stored in directory: /home/jupyterlab/.cache/pip/wheels/81/33/2c/eb7bd2194d1365d3645bf66fb94fdbd7355794b0a6307c651d
# Successfully built dash dash-core-components dash-html-components dash_renderer dash-table
# Installing collected packages: dash-table, dash_renderer, dash-html-components, dash-core-components, future, flask-compress, dash
#   Attempting uninstall: dash-table
#     Found existing installation: dash-table 5.0.0
#     Uninstalling dash-table-5.0.0:
#       Successfully uninstalled dash-table-5.0.0
#   Attempting uninstall: dash-html-components
#     Found existing installation: dash-html-components 2.0.0
#     Uninstalling dash-html-components-2.0.0:
#       Successfully uninstalled dash-html-components-2.0.0
#   Attempting uninstall: dash-core-components
#     Found existing installation: dash-core-components 2.0.0
#     Uninstalling dash-core-components-2.0.0:
#       Successfully uninstalled dash-core-components-2.0.0
#   Attempting uninstall: dash
#     Found existing installation: dash 2.18.2
#     Uninstalling dash-2.18.2:
#       Successfully uninstalled dash-2.18.2
# Successfully installed dash-1.19.0 dash-core-components-1.15.0 dash-html-components-1.1.2 dash-table-4.11.2 dash_renderer-1.9.0 flask-compress-1.17 future-1.0.0
# Collecting jupyter_dash
#   Downloading jupyter_dash-0.4.2-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: dash in /opt/conda/lib/python3.12/site-packages (from jupyter_dash) (1.19.0)
# Requirement already satisfied: requests in /opt/conda/lib/python3.12/site-packages (from jupyter_dash) (2.32.3)
# Requirement already satisfied: flask in /opt/conda/lib/python3.12/site-packages (from jupyter_dash) (3.0.3)
# Requirement already satisfied: retrying in /opt/conda/lib/python3.12/site-packages (from jupyter_dash) (1.3.4)
# Requirement already satisfied: ipython in /opt/conda/lib/python3.12/site-packages (from jupyter_dash) (8.31.0)
# Requirement already satisfied: ipykernel in /opt/conda/lib/python3.12/site-packages (from jupyter_dash) (6.29.5)
# Collecting ansi2html (from jupyter_dash)
#   Downloading ansi2html-1.9.2-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: nest-asyncio in /opt/conda/lib/python3.12/site-packages (from jupyter_dash) (1.6.0)
# Requirement already satisfied: flask-compress in /opt/conda/lib/python3.12/site-packages (from dash->jupyter_dash) (1.17)
# Requirement already satisfied: plotly in /opt/conda/lib/python3.12/site-packages (from dash->jupyter_dash) (5.24.1)
# Requirement already satisfied: dash_renderer==1.9.0 in /opt/conda/lib/python3.12/site-packages (from dash->jupyter_dash) (1.9.0)
# Requirement already satisfied: dash-core-components==1.15.0 in /opt/conda/lib/python3.12/site-packages (from dash->jupyter_dash) (1.15.0)
# Requirement already satisfied: dash-html-components==1.1.2 in /opt/conda/lib/python3.12/site-packages (from dash->jupyter_dash) (1.1.2)
# Requirement already satisfied: dash-table==4.11.2 in /opt/conda/lib/python3.12/site-packages (from dash->jupyter_dash) (4.11.2)
# Requirement already satisfied: future in /opt/conda/lib/python3.12/site-packages (from dash->jupyter_dash) (1.0.0)
# Requirement already satisfied: Werkzeug>=3.0.0 in /opt/conda/lib/python3.12/site-packages (from flask->jupyter_dash) (3.0.6)
# Requirement already satisfied: Jinja2>=3.1.2 in /opt/conda/lib/python3.12/site-packages (from flask->jupyter_dash) (3.1.5)
# Requirement already satisfied: itsdangerous>=2.1.2 in /opt/conda/lib/python3.12/site-packages (from flask->jupyter_dash) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in /opt/conda/lib/python3.12/site-packages (from flask->jupyter_dash) (8.1.8)
# Requirement already satisfied: blinker>=1.6.2 in /opt/conda/lib/python3.12/site-packages (from flask->jupyter_dash) (1.9.0)
# Requirement already satisfied: comm>=0.1.1 in /opt/conda/lib/python3.12/site-packages (from ipykernel->jupyter_dash) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /opt/conda/lib/python3.12/site-packages (from ipykernel->jupyter_dash) (1.8.12)
# Requirement already satisfied: jupyter-client>=6.1.12 in /opt/conda/lib/python3.12/site-packages (from ipykernel->jupyter_dash) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /opt/conda/lib/python3.12/site-packages (from ipykernel->jupyter_dash) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /opt/conda/lib/python3.12/site-packages (from ipykernel->jupyter_dash) (0.1.7)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.12/site-packages (from ipykernel->jupyter_dash) (24.2)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.12/site-packages (from ipykernel->jupyter_dash) (6.1.1)
# Requirement already satisfied: pyzmq>=24 in /opt/conda/lib/python3.12/site-packages (from ipykernel->jupyter_dash) (26.2.0)
# Requirement already satisfied: tornado>=6.1 in /opt/conda/lib/python3.12/site-packages (from ipykernel->jupyter_dash) (6.4.2)
# Requirement already satisfied: traitlets>=5.4.0 in /opt/conda/lib/python3.12/site-packages (from ipykernel->jupyter_dash) (5.14.3)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.12/site-packages (from ipython->jupyter_dash) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/lib/python3.12/site-packages (from ipython->jupyter_dash) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/lib/python3.12/site-packages (from ipython->jupyter_dash) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /opt/conda/lib/python3.12/site-packages (from ipython->jupyter_dash) (3.0.50)
# Requirement already satisfied: pygments>=2.4.0 in /opt/conda/lib/python3.12/site-packages (from ipython->jupyter_dash) (2.19.1)
# Requirement already satisfied: stack_data in /opt/conda/lib/python3.12/site-packages (from ipython->jupyter_dash) (0.6.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests->jupyter_dash) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.12/site-packages (from requests->jupyter_dash) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.12/site-packages (from requests->jupyter_dash) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.12/site-packages (from requests->jupyter_dash) (2024.12.14)
# Requirement already satisfied: six>=1.7.0 in /opt/conda/lib/python3.12/site-packages (from retrying->jupyter_dash) (1.17.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /opt/conda/lib/python3.12/site-packages (from jedi>=0.16->ipython->jupyter_dash) (0.8.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.12/site-packages (from Jinja2>=3.1.2->flask->jupyter_dash) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.12/site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter_dash) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in /opt/conda/lib/python3.12/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter_dash) (4.3.6)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/lib/python3.12/site-packages (from pexpect>4.3->ipython->jupyter_dash) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython->jupyter_dash) (0.2.13)
# Requirement already satisfied: brotli in /opt/conda/lib/python3.12/site-packages (from flask-compress->dash->jupyter_dash) (1.1.0)
# Requirement already satisfied: zstandard in /opt/conda/lib/python3.12/site-packages (from flask-compress->dash->jupyter_dash) (0.23.0)
# Requirement already satisfied: tenacity>=6.2.0 in /opt/conda/lib/python3.12/site-packages (from plotly->dash->jupyter_dash) (9.0.0)
# Requirement already satisfied: executing>=1.2.0 in /opt/conda/lib/python3.12/site-packages (from stack_data->ipython->jupyter_dash) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/conda/lib/python3.12/site-packages (from stack_data->ipython->jupyter_dash) (3.0.0)
# Requirement already satisfied: pure_eval in /opt/conda/lib/python3.12/site-packages (from stack_data->ipython->jupyter_dash) (0.2.3)
# Downloading jupyter_dash-0.4.2-py3-none-any.whl (23 kB)
# Downloading ansi2html-1.9.2-py3-none-any.whl (17 kB)
# Installing collected packages: ansi2html, jupyter_dash
# Successfully installed ansi2html-1.9.2 jupyter_dash-0.4.2
# Requirement already satisfied: plotly in /opt/conda/lib/python3.12/site-packages (5.24.1)
# Collecting plotly
#   Downloading plotly-6.0.0-py3-none-any.whl.metadata (5.6 kB)
# Collecting narwhals>=1.15.1 (from plotly)
#   Downloading narwhals-1.27.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.12/site-packages (from plotly) (24.2)
# Downloading plotly-6.0.0-py3-none-any.whl (14.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.8/14.8 MB 175.1 MB/s eta 0:00:00
# Downloading narwhals-1.27.1-py3-none-any.whl (308 kB)
# Installing collected packages: narwhals, plotly
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.24.1
#     Uninstalling plotly-5.24.1:
#       Successfully uninstalled plotly-5.24.1
# Successfully installed narwhals-1.27.1 plotly-6.0.0
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 8
#       3 get_ipython().system('pip install jupyter_dash')
#       5 get_ipython().system('pip install --upgrade plotly')
# ----> 8 import pandas as pd
#       9 import dash
#      10 import dash_html_components as html
#
# ModuleNotFoundError: No module named 'pandas'

# %%
# !pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-2.2.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (89 kB)
# Collecting numpy>=1.26.0 (from pandas)
#   Downloading numpy-2.2.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.12/site-packages (from pandas) (2024.2)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2025.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-2.2.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.7/12.7 MB 175.3 MB/s eta 0:00:00
# Downloading numpy-2.2.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.1/16.1 MB 157.3 MB/s eta 0:00:00
# Downloading tzdata-2025.1-py2.py3-none-any.whl (346 kB)
# Installing collected packages: tzdata, numpy, pandas
# Successfully installed numpy-2.2.3 pandas-2.2.3 tzdata-2025.1

# %%
# !pip install dash==1.19.0  

# !pip install jupyter_dash 

# !pip install --upgrade plotly


import pandas as pd
import dash
import dash_html_components as html
import dash_core_components as dcc
from dash.dependencies import Input, Output
from jupyter_dash import JupyterDash
import plotly.graph_objects as go

spacex_df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_dash.csv")
max_payload = spacex_df['Payload Mass (kg)'].max()
min_payload = spacex_df['Payload Mass (kg)'].min()

# Create a dash application
app = JupyterDash(__name__)

# Create an app layout
app.layout = html.Div(children=[
    html.H1('SpaceX Launch Records Dash',
            style={'textAlign': 'center', 'color': '#503D36','font-size': 40}),
 
    # TASK 1: Add a dropdown list to enable Launch Site selection
    dcc.Dropdown(
        id='site-dropdown',
        options=[
            {'label': 'All Sites', 'value': 'ALL'},
            {'label': 'CCAFS LC-40', 'value': 'CCAFS LC-40'},
            {'label': 'CCAFS SLC-40', 'value': 'CCAFS SLC-40'},
            {'label': 'KSC LC-39A', 'value': 'KSC LC-39A'},
            {'label': 'VAFB SLC-4E', 'value': 'VAFB SLC-4E'}
        ],
        value='ALL',
        placeholder="Place holder site here",
        searchable=True
    ),
    html.Br(),
 
    # TASK 2: Add a pie chart to show the total successful launches count for all sites
    html.Div(dcc.Graph(id='success-pie-chart')),
    html.Br(),
 
    html.P("Payload range (Kg):"),
    dcc.RangeSlider(
        id='payload-slider',
        min=0, 
        max=10000, 
        step=1000,
        marks={0: '0(Kg)',2500: '2500 (Kg)', 5000: '5000 (Kg)',7500: '7500 (Kg)', 10000: '10000 (Kg)'},
        value=[min_payload, max_payload]
    ),
 
     # TASK 4: Add a scatter chart to show the correlation between payload and launch success
     html.Div(dcc.Graph(id='success-payload-scatter-chart')),
    ])
 

# TASK 2:
@app.callback(
    Output(component_id='success-pie-chart', component_property='figure'),
    Input(component_id='site-dropdown', component_property='value')
)
def get_pie_chart(entered_site):
    filtered_df = spacex_df
    if entered_site == 'ALL':
        fig = px.pie(filtered_df, values='class', 
                    names='Launch Site', 
                    title='Total Successful Launches by Site')
    else:
        filtered_df = spacex_df[spacex_df['Launch Site'] == entered_site]
        filtered_df = filtered_df.groupby(['Launch Site','class']).size().reset_index(name='class count')
        fig = px.pie(filtered_df, values='class count', 
                     names='class',
                     title=f'Total Sucessful Launches for Site {entered_site}')
    return fig

# TASK 4:
@app.callback(
    Output(component_id='success-payload-scatter-chart', component_property='figure'),
    [Input(component_id='site-dropdown', component_property='value'), 
    Input(component_id="payload-slider", component_property="value")]
)
def get_scatter_chart(entered_site, payload_range):
    filtered_df = spacex_df[(spacex_df['Payload Mass (kg)']>= payload_range[0]) &
                            (spacex_df['Payload Mass (kg)']<= payload_range[1])]
    if entered_site == 'ALL':
        fig = px.scatter(filtered_df, x='Payload Mass (kg)', y='class',
                         color='Booster Version Category',
                         title='Payload vs. Success for All Sites')
    else:
        filtered_df = filtered_df[filtered_df['Launch Site']== entered_site]
        fig = px.scatter(filtered_df, x='Payload Mass (kg)', y='class',
                         color='Booster Version Category',
                         title=f'Payload vs. Success for site {entered_site}')
    return fig

# Run the app
if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
# Requirement already satisfied: dash==1.19.0 in /opt/conda/lib/python3.12/site-packages (1.19.0)
# Requirement already satisfied: Flask>=1.0.4 in /opt/conda/lib/python3.12/site-packages (from dash==1.19.0) (3.0.3)
# Requirement already satisfied: flask-compress in /opt/conda/lib/python3.12/site-packages (from dash==1.19.0) (1.17)
# Requirement already satisfied: plotly in /opt/conda/lib/python3.12/site-packages (from dash==1.19.0) (6.0.0)
# Requirement already satisfied: dash_renderer==1.9.0 in /opt/conda/lib/python3.12/site-packages (from dash==1.19.0) (1.9.0)
# Requirement already satisfied: dash-core-components==1.15.0 in /opt/conda/lib/python3.12/site-packages (from dash==1.19.0) (1.15.0)
# Requirement already satisfied: dash-html-components==1.1.2 in /opt/conda/lib/python3.12/site-packages (from dash==1.19.0) (1.1.2)
# Requirement already satisfied: dash-table==4.11.2 in /opt/conda/lib/python3.12/site-packages (from dash==1.19.0) (4.11.2)
# Requirement already satisfied: future in /opt/conda/lib/python3.12/site-packages (from dash==1.19.0) (1.0.0)
# Requirement already satisfied: Werkzeug>=3.0.0 in /opt/conda/lib/python3.12/site-packages (from Flask>=1.0.4->dash==1.19.0) (3.0.6)
# Requirement already satisfied: Jinja2>=3.1.2 in /opt/conda/lib/python3.12/site-packages (from Flask>=1.0.4->dash==1.19.0) (3.1.5)
# Requirement already satisfied: itsdangerous>=2.1.2 in /opt/conda/lib/python3.12/site-packages (from Flask>=1.0.4->dash==1.19.0) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in /opt/conda/lib/python3.12/site-packages (from Flask>=1.0.4->dash==1.19.0) (8.1.8)
# Requirement already satisfied: blinker>=1.6.2 in /opt/conda/lib/python3.12/site-packages (from Flask>=1.0.4->dash==1.19.0) (1.9.0)
# Requirement already satisfied: brotli in /opt/conda/lib/python3.12/site-packages (from flask-compress->dash==1.19.0) (1.1.0)
# Requirement already satisfied: zstandard in /opt/conda/lib/python3.12/site-packages (from flask-compress->dash==1.19.0) (0.23.0)
# Requirement already satisfied: narwhals>=1.15.1 in /opt/conda/lib/python3.12/site-packages (from plotly->dash==1.19.0) (1.27.1)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.12/site-packages (from plotly->dash==1.19.0) (24.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.12/site-packages (from Jinja2>=3.1.2->Flask>=1.0.4->dash==1.19.0) (3.0.2)
# Requirement already satisfied: jupyter_dash in /opt/conda/lib/python3.12/site-packages (0.4.2)
# Requirement already satisfied: dash in /opt/conda/lib/python3.12/site-packages (from jupyter_dash) (1.19.0)
# Requirement already satisfied: requests in /opt/conda/lib/python3.12/site-packages (from jupyter_dash) (2.32.3)
# Requirement already satisfied: flask in /opt/conda/lib/python3.12/site-packages (from jupyter_dash) (3.0.3)
# Requirement already satisfied: retrying in /opt/conda/lib/python3.12/site-packages (from jupyter_dash) (1.3.4)
# Requirement already satisfied: ipython in /opt/conda/lib/python3.12/site-packages (from jupyter_dash) (8.31.0)
# Requirement already satisfied: ipykernel in /opt/conda/lib/python3.12/site-packages (from jupyter_dash) (6.29.5)
# Requirement already satisfied: ansi2html in /opt/conda/lib/python3.12/site-packages (from jupyter_dash) (1.9.2)
# Requirement already satisfied: nest-asyncio in /opt/conda/lib/python3.12/site-packages (from jupyter_dash) (1.6.0)
# Requirement already satisfied: flask-compress in /opt/conda/lib/python3.12/site-packages (from dash->jupyter_dash) (1.17)
# Requirement already satisfied: plotly in /opt/conda/lib/python3.12/site-packages (from dash->jupyter_dash) (6.0.0)
# Requirement already satisfied: dash_renderer==1.9.0 in /opt/conda/lib/python3.12/site-packages (from dash->jupyter_dash) (1.9.0)
# Requirement already satisfied: dash-core-components==1.15.0 in /opt/conda/lib/python3.12/site-packages (from dash->jupyter_dash) (1.15.0)
# Requirement already satisfied: dash-html-components==1.1.2 in /opt/conda/lib/python3.12/site-packages (from dash->jupyter_dash) (1.1.2)
# Requirement already satisfied: dash-table==4.11.2 in /opt/conda/lib/python3.12/site-packages (from dash->jupyter_dash) (4.11.2)
# Requirement already satisfied: future in /opt/conda/lib/python3.12/site-packages (from dash->jupyter_dash) (1.0.0)
# Requirement already satisfied: Werkzeug>=3.0.0 in /opt/conda/lib/python3.12/site-packages (from flask->jupyter_dash) (3.0.6)
# Requirement already satisfied: Jinja2>=3.1.2 in /opt/conda/lib/python3.12/site-packages (from flask->jupyter_dash) (3.1.5)
# Requirement already satisfied: itsdangerous>=2.1.2 in /opt/conda/lib/python3.12/site-packages (from flask->jupyter_dash) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in /opt/conda/lib/python3.12/site-packages (from flask->jupyter_dash) (8.1.8)
# Requirement already satisfied: blinker>=1.6.2 in /opt/conda/lib/python3.12/site-packages (from flask->jupyter_dash) (1.9.0)
# Requirement already satisfied: comm>=0.1.1 in /opt/conda/lib/python3.12/site-packages (from ipykernel->jupyter_dash) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /opt/conda/lib/python3.12/site-packages (from ipykernel->jupyter_dash) (1.8.12)
# Requirement already satisfied: jupyter-client>=6.1.12 in /opt/conda/lib/python3.12/site-packages (from ipykernel->jupyter_dash) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /opt/conda/lib/python3.12/site-packages (from ipykernel->jupyter_dash) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /opt/conda/lib/python3.12/site-packages (from ipykernel->jupyter_dash) (0.1.7)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.12/site-packages (from ipykernel->jupyter_dash) (24.2)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.12/site-packages (from ipykernel->jupyter_dash) (6.1.1)
# Requirement already satisfied: pyzmq>=24 in /opt/conda/lib/python3.12/site-packages (from ipykernel->jupyter_dash) (26.2.0)
# Requirement already satisfied: tornado>=6.1 in /opt/conda/lib/python3.12/site-packages (from ipykernel->jupyter_dash) (6.4.2)
# Requirement already satisfied: traitlets>=5.4.0 in /opt/conda/lib/python3.12/site-packages (from ipykernel->jupyter_dash) (5.14.3)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.12/site-packages (from ipython->jupyter_dash) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/lib/python3.12/site-packages (from ipython->jupyter_dash) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/lib/python3.12/site-packages (from ipython->jupyter_dash) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /opt/conda/lib/python3.12/site-packages (from ipython->jupyter_dash) (3.0.50)
# Requirement already satisfied: pygments>=2.4.0 in /opt/conda/lib/python3.12/site-packages (from ipython->jupyter_dash) (2.19.1)
# Requirement already satisfied: stack_data in /opt/conda/lib/python3.12/site-packages (from ipython->jupyter_dash) (0.6.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests->jupyter_dash) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.12/site-packages (from requests->jupyter_dash) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.12/site-packages (from requests->jupyter_dash) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.12/site-packages (from requests->jupyter_dash) (2024.12.14)
# Requirement already satisfied: six>=1.7.0 in /opt/conda/lib/python3.12/site-packages (from retrying->jupyter_dash) (1.17.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /opt/conda/lib/python3.12/site-packages (from jedi>=0.16->ipython->jupyter_dash) (0.8.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.12/site-packages (from Jinja2>=3.1.2->flask->jupyter_dash) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.12/site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter_dash) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in /opt/conda/lib/python3.12/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter_dash) (4.3.6)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/lib/python3.12/site-packages (from pexpect>4.3->ipython->jupyter_dash) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython->jupyter_dash) (0.2.13)
# Requirement already satisfied: brotli in /opt/conda/lib/python3.12/site-packages (from flask-compress->dash->jupyter_dash) (1.1.0)
# Requirement already satisfied: zstandard in /opt/conda/lib/python3.12/site-packages (from flask-compress->dash->jupyter_dash) (0.23.0)
# Requirement already satisfied: narwhals>=1.15.1 in /opt/conda/lib/python3.12/site-packages (from plotly->dash->jupyter_dash) (1.27.1)
# Requirement already satisfied: executing>=1.2.0 in /opt/conda/lib/python3.12/site-packages (from stack_data->ipython->jupyter_dash) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/conda/lib/python3.12/site-packages (from stack_data->ipython->jupyter_dash) (3.0.0)
# Requirement already satisfied: pure_eval in /opt/conda/lib/python3.12/site-packages (from stack_data->ipython->jupyter_dash) (0.2.3)
# Requirement already satisfied: plotly in /opt/conda/lib/python3.12/site-packages (6.0.0)
# Requirement already satisfied: narwhals>=1.15.1 in /opt/conda/lib/python3.12/site-packages (from plotly) (1.27.1)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.12/site-packages (from plotly) (24.2)
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[8], line 9
#       5 get_ipython().system('pip install --upgrade plotly')
#       8 import pandas as pd
# ----> 9 import dash
#      10 import dash_html_components as html
#      11 import dash_core_components as dcc
#
# File /opt/conda/lib/python3.12/site-packages/dash/__init__.py:5
#       1 # pylint: disable=C0413
#       2 # __plotly_dash is for the "make sure you don't have a dash.py" check
#       3 # must come before any other imports.
#       4 __plotly_dash = True
# ----> 5 from .dash import Dash, no_update  # noqa: F401,E402
#       6 from . import dependencies  # noqa: F401,E402
#       7 from . import development  # noqa: F401,E402
#
# File /opt/conda/lib/python3.12/site-packages/dash/dash.py:22
#      20 import flask
#      21 from flask_compress import Compress
# ---> 22 from werkzeug.debug.tbtools import get_current_traceback
#      23 from pkg_resources import get_distribution, parse_version
#      25 import plotly
#
# ImportError: cannot import name 'get_current_traceback' from 'werkzeug.debug.tbtools' (/opt/conda/lib/python3.12/site-packages/werkzeug/debug/tbtools.py)

# %%
# !pip show dash werkzeug
# Out:
# Name: dash
# Version: 1.19.0
# Summary: A Python framework for building reactive web-apps. Developed by Plotly.
# Home-page: https://plotly.com/dash
# Author: Chris Parmer
# Author-email: chris@plotly.com
# License: MIT
# Location: /opt/conda/lib/python3.12/site-packages
# Requires: dash-core-components, dash-html-components, dash-table, dash_renderer, Flask, flask-compress, future, plotly
# Required-by: jupyter-dash
# ---
# Name: Werkzeug
# Version: 3.0.6
# Summary: The comprehensive WSGI web application library.
# Home-page:
# Author:
# Author-email:
# License:
# Location: /opt/conda/lib/python3.12/site-packages
# Requires: MarkupSafe
# Required-by: Flask

# %%
# !pip install --upgrade dash werkzeug
# Out:
# Requirement already satisfied: dash in /opt/conda/lib/python3.12/site-packages (1.19.0)
# Collecting dash
#   Using cached dash-2.18.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: werkzeug in /opt/conda/lib/python3.12/site-packages (3.0.6)
# Collecting werkzeug
#   Downloading werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in /opt/conda/lib/python3.12/site-packages (from dash) (3.0.3)
# Requirement already satisfied: plotly>=5.0.0 in /opt/conda/lib/python3.12/site-packages (from dash) (6.0.0)
# Collecting dash-html-components==2.0.0 (from dash)
#   Using cached dash_html_components-2.0.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting dash-core-components==2.0.0 (from dash)
#   Using cached dash_core_components-2.0.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting dash-table==5.0.0 (from dash)
#   Using cached dash_table-5.0.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: importlib-metadata in /opt/conda/lib/python3.12/site-packages (from dash) (8.6.1)
# Requirement already satisfied: typing-extensions>=4.1.1 in /opt/conda/lib/python3.12/site-packages (from dash) (4.12.2)
# Requirement already satisfied: requests in /opt/conda/lib/python3.12/site-packages (from dash) (2.32.3)
# Requirement already satisfied: retrying in /opt/conda/lib/python3.12/site-packages (from dash) (1.3.4)
# Requirement already satisfied: nest-asyncio in /opt/conda/lib/python3.12/site-packages (from dash) (1.6.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.12/site-packages (from dash) (75.8.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/lib/python3.12/site-packages (from werkzeug) (3.0.2)
# Requirement already satisfied: Jinja2>=3.1.2 in /opt/conda/lib/python3.12/site-packages (from Flask<3.1,>=1.0.4->dash) (3.1.5)
# Requirement already satisfied: itsdangerous>=2.1.2 in /opt/conda/lib/python3.12/site-packages (from Flask<3.1,>=1.0.4->dash) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in /opt/conda/lib/python3.12/site-packages (from Flask<3.1,>=1.0.4->dash) (8.1.8)
# Requirement already satisfied: blinker>=1.6.2 in /opt/conda/lib/python3.12/site-packages (from Flask<3.1,>=1.0.4->dash) (1.9.0)
# Requirement already satisfied: narwhals>=1.15.1 in /opt/conda/lib/python3.12/site-packages (from plotly>=5.0.0->dash) (1.27.1)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.12/site-packages (from plotly>=5.0.0->dash) (24.2)
# Requirement already satisfied: zipp>=3.20 in /opt/conda/lib/python3.12/site-packages (from importlib-metadata->dash) (3.21.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests->dash) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.12/site-packages (from requests->dash) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.12/site-packages (from requests->dash) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.12/site-packages (from requests->dash) (2024.12.14)
# Requirement already satisfied: six>=1.7.0 in /opt/conda/lib/python3.12/site-packages (from retrying->dash) (1.17.0)
# Using cached dash-2.18.2-py3-none-any.whl (7.8 MB)
# Using cached dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Using cached dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Using cached dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# Installing collected packages: dash-table, dash-html-components, dash-core-components, dash
#   Attempting uninstall: dash-table
#     Found existing installation: dash_table 4.11.2
#     Uninstalling dash_table-4.11.2:
#       Successfully uninstalled dash_table-4.11.2
#   Attempting uninstall: dash-html-components
#     Found existing installation: dash_html_components 1.1.2
#     Uninstalling dash_html_components-1.1.2:
#       Successfully uninstalled dash_html_components-1.1.2
#   Attempting uninstall: dash-core-components
#     Found existing installation: dash_core_components 1.15.0
#     Uninstalling dash_core_components-1.15.0:
#       Successfully uninstalled dash_core_components-1.15.0
#   Attempting uninstall: dash
#     Found existing installation: dash 1.19.0
#     Uninstalling dash-1.19.0:
#       Successfully uninstalled dash-1.19.0
# Successfully installed dash-2.18.2 dash-core-components-2.0.0 dash-html-components-2.0.0 dash-table-5.0.0

# %%
# !pip install dash==1.19.0  

# !pip install jupyter_dash 

# !pip install --upgrade plotly


import pandas as pd
import dash
import dash_html_components as html
import dash_core_components as dcc
from dash.dependencies import Input, Output
from jupyter_dash import JupyterDash
import plotly.graph_objects as go

spacex_df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_dash.csv")
max_payload = spacex_df['Payload Mass (kg)'].max()
min_payload = spacex_df['Payload Mass (kg)'].min()

# Create a dash application
app = JupyterDash(__name__)

# Create an app layout
app.layout = html.Div(children=[
    html.H1('SpaceX Launch Records Dash',
            style={'textAlign': 'center', 'color': '#503D36','font-size': 40}),
 
    # TASK 1: Add a dropdown list to enable Launch Site selection
    dcc.Dropdown(
        id='site-dropdown',
        options=[
            {'label': 'All Sites', 'value': 'ALL'},
            {'label': 'CCAFS LC-40', 'value': 'CCAFS LC-40'},
            {'label': 'CCAFS SLC-40', 'value': 'CCAFS SLC-40'},
            {'label': 'KSC LC-39A', 'value': 'KSC LC-39A'},
            {'label': 'VAFB SLC-4E', 'value': 'VAFB SLC-4E'}
        ],
        value='ALL',
        placeholder="Place holder site here",
        searchable=True
    ),
    html.Br(),
 
    # TASK 2: Add a pie chart to show the total successful launches count for all sites
    html.Div(dcc.Graph(id='success-pie-chart')),
    html.Br(),
 
    html.P("Payload range (Kg):"),
    dcc.RangeSlider(
        id='payload-slider',
        min=0, 
        max=10000, 
        step=1000,
        marks={0: '0(Kg)',2500: '2500 (Kg)', 5000: '5000 (Kg)',7500: '7500 (Kg)', 10000: '10000 (Kg)'},
        value=[min_payload, max_payload]
    ),
 
     # TASK 4: Add a scatter chart to show the correlation between payload and launch success
     html.Div(dcc.Graph(id='success-payload-scatter-chart')),
    ])
 

# TASK 2:
@app.callback(
    Output(component_id='success-pie-chart', component_property='figure'),
    Input(component_id='site-dropdown', component_property='value')
)
def get_pie_chart(entered_site):
    filtered_df = spacex_df
    if entered_site == 'ALL':
        fig = px.pie(filtered_df, values='class', 
                    names='Launch Site', 
                    title='Total Successful Launches by Site')
    else:
        filtered_df = spacex_df[spacex_df['Launch Site'] == entered_site]
        filtered_df = filtered_df.groupby(['Launch Site','class']).size().reset_index(name='class count')
        fig = px.pie(filtered_df, values='class count', 
                     names='class',
                     title=f'Total Sucessful Launches for Site {entered_site}')
    return fig

# TASK 4:
@app.callback(
    Output(component_id='success-payload-scatter-chart', component_property='figure'),
    [Input(component_id='site-dropdown', component_property='value'), 
    Input(component_id="payload-slider", component_property="value")]
)
def get_scatter_chart(entered_site, payload_range):
    filtered_df = spacex_df[(spacex_df['Payload Mass (kg)']>= payload_range[0]) &
                            (spacex_df['Payload Mass (kg)']<= payload_range[1])]
    if entered_site == 'ALL':
        fig = px.scatter(filtered_df, x='Payload Mass (kg)', y='class',
                         color='Booster Version Category',
                         title='Payload vs. Success for All Sites')
    else:
        filtered_df = filtered_df[filtered_df['Launch Site']== entered_site]
        fig = px.scatter(filtered_df, x='Payload Mass (kg)', y='class',
                         color='Booster Version Category',
                         title=f'Payload vs. Success for site {entered_site}')
    return fig

# Run the app
if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
# Collecting dash==1.19.0
#   Using cached dash-1.19.0-py3-none-any.whl
# Requirement already satisfied: Flask>=1.0.4 in /opt/conda/lib/python3.12/site-packages (from dash==1.19.0) (3.0.3)
# Requirement already satisfied: flask-compress in /opt/conda/lib/python3.12/site-packages (from dash==1.19.0) (1.17)
# Requirement already satisfied: plotly in /opt/conda/lib/python3.12/site-packages (from dash==1.19.0) (6.0.0)
# Requirement already satisfied: dash_renderer==1.9.0 in /opt/conda/lib/python3.12/site-packages (from dash==1.19.0) (1.9.0)
# Collecting dash-core-components==1.15.0 (from dash==1.19.0)
#   Using cached dash_core_components-1.15.0-py3-none-any.whl
# Collecting dash-html-components==1.1.2 (from dash==1.19.0)
#   Using cached dash_html_components-1.1.2-py3-none-any.whl
# Collecting dash-table==4.11.2 (from dash==1.19.0)
#   Using cached dash_table-4.11.2-py3-none-any.whl
# Requirement already satisfied: future in /opt/conda/lib/python3.12/site-packages (from dash==1.19.0) (1.0.0)
# Requirement already satisfied: Werkzeug>=3.0.0 in /opt/conda/lib/python3.12/site-packages (from Flask>=1.0.4->dash==1.19.0) (3.0.6)
# Requirement already satisfied: Jinja2>=3.1.2 in /opt/conda/lib/python3.12/site-packages (from Flask>=1.0.4->dash==1.19.0) (3.1.5)
# Requirement already satisfied: itsdangerous>=2.1.2 in /opt/conda/lib/python3.12/site-packages (from Flask>=1.0.4->dash==1.19.0) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in /opt/conda/lib/python3.12/site-packages (from Flask>=1.0.4->dash==1.19.0) (8.1.8)
# Requirement already satisfied: blinker>=1.6.2 in /opt/conda/lib/python3.12/site-packages (from Flask>=1.0.4->dash==1.19.0) (1.9.0)
# Requirement already satisfied: brotli in /opt/conda/lib/python3.12/site-packages (from flask-compress->dash==1.19.0) (1.1.0)
# Requirement already satisfied: zstandard in /opt/conda/lib/python3.12/site-packages (from flask-compress->dash==1.19.0) (0.23.0)
# Requirement already satisfied: narwhals>=1.15.1 in /opt/conda/lib/python3.12/site-packages (from plotly->dash==1.19.0) (1.27.1)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.12/site-packages (from plotly->dash==1.19.0) (24.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.12/site-packages (from Jinja2>=3.1.2->Flask>=1.0.4->dash==1.19.0) (3.0.2)
# Installing collected packages: dash-table, dash-html-components, dash-core-components, dash
#   Attempting uninstall: dash-table
#     Found existing installation: dash-table 5.0.0
#     Uninstalling dash-table-5.0.0:
#       Successfully uninstalled dash-table-5.0.0
#   Attempting uninstall: dash-html-components
#     Found existing installation: dash-html-components 2.0.0
#     Uninstalling dash-html-components-2.0.0:
#       Successfully uninstalled dash-html-components-2.0.0
#   Attempting uninstall: dash-core-components
#     Found existing installation: dash-core-components 2.0.0
#     Uninstalling dash-core-components-2.0.0:
#       Successfully uninstalled dash-core-components-2.0.0
#   Attempting uninstall: dash
#     Found existing installation: dash 2.18.2
#     Uninstalling dash-2.18.2:
#       Successfully uninstalled dash-2.18.2
# Successfully installed dash-1.19.0 dash-core-components-1.15.0 dash-html-components-1.1.2 dash-table-4.11.2
# Requirement already satisfied: jupyter_dash in /opt/conda/lib/python3.12/site-packages (0.4.2)
# Requirement already satisfied: dash in /opt/conda/lib/python3.12/site-packages (from jupyter_dash) (1.19.0)
# Requirement already satisfied: requests in /opt/conda/lib/python3.12/site-packages (from jupyter_dash) (2.32.3)
# Requirement already satisfied: flask in /opt/conda/lib/python3.12/site-packages (from jupyter_dash) (3.0.3)
# Requirement already satisfied: retrying in /opt/conda/lib/python3.12/site-packages (from jupyter_dash) (1.3.4)
# Requirement already satisfied: ipython in /opt/conda/lib/python3.12/site-packages (from jupyter_dash) (8.31.0)
# Requirement already satisfied: ipykernel in /opt/conda/lib/python3.12/site-packages (from jupyter_dash) (6.29.5)
# Requirement already satisfied: ansi2html in /opt/conda/lib/python3.12/site-packages (from jupyter_dash) (1.9.2)
# Requirement already satisfied: nest-asyncio in /opt/conda/lib/python3.12/site-packages (from jupyter_dash) (1.6.0)
# Requirement already satisfied: flask-compress in /opt/conda/lib/python3.12/site-packages (from dash->jupyter_dash) (1.17)
# Requirement already satisfied: plotly in /opt/conda/lib/python3.12/site-packages (from dash->jupyter_dash) (6.0.0)
# Requirement already satisfied: dash_renderer==1.9.0 in /opt/conda/lib/python3.12/site-packages (from dash->jupyter_dash) (1.9.0)
# Requirement already satisfied: dash-core-components==1.15.0 in /opt/conda/lib/python3.12/site-packages (from dash->jupyter_dash) (1.15.0)
# Requirement already satisfied: dash-html-components==1.1.2 in /opt/conda/lib/python3.12/site-packages (from dash->jupyter_dash) (1.1.2)
# Requirement already satisfied: dash-table==4.11.2 in /opt/conda/lib/python3.12/site-packages (from dash->jupyter_dash) (4.11.2)
# Requirement already satisfied: future in /opt/conda/lib/python3.12/site-packages (from dash->jupyter_dash) (1.0.0)
# Requirement already satisfied: Werkzeug>=3.0.0 in /opt/conda/lib/python3.12/site-packages (from flask->jupyter_dash) (3.0.6)
# Requirement already satisfied: Jinja2>=3.1.2 in /opt/conda/lib/python3.12/site-packages (from flask->jupyter_dash) (3.1.5)
# Requirement already satisfied: itsdangerous>=2.1.2 in /opt/conda/lib/python3.12/site-packages (from flask->jupyter_dash) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in /opt/conda/lib/python3.12/site-packages (from flask->jupyter_dash) (8.1.8)
# Requirement already satisfied: blinker>=1.6.2 in /opt/conda/lib/python3.12/site-packages (from flask->jupyter_dash) (1.9.0)
# Requirement already satisfied: comm>=0.1.1 in /opt/conda/lib/python3.12/site-packages (from ipykernel->jupyter_dash) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /opt/conda/lib/python3.12/site-packages (from ipykernel->jupyter_dash) (1.8.12)
# Requirement already satisfied: jupyter-client>=6.1.12 in /opt/conda/lib/python3.12/site-packages (from ipykernel->jupyter_dash) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /opt/conda/lib/python3.12/site-packages (from ipykernel->jupyter_dash) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /opt/conda/lib/python3.12/site-packages (from ipykernel->jupyter_dash) (0.1.7)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.12/site-packages (from ipykernel->jupyter_dash) (24.2)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.12/site-packages (from ipykernel->jupyter_dash) (6.1.1)
# Requirement already satisfied: pyzmq>=24 in /opt/conda/lib/python3.12/site-packages (from ipykernel->jupyter_dash) (26.2.0)
# Requirement already satisfied: tornado>=6.1 in /opt/conda/lib/python3.12/site-packages (from ipykernel->jupyter_dash) (6.4.2)
# Requirement already satisfied: traitlets>=5.4.0 in /opt/conda/lib/python3.12/site-packages (from ipykernel->jupyter_dash) (5.14.3)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.12/site-packages (from ipython->jupyter_dash) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/lib/python3.12/site-packages (from ipython->jupyter_dash) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/lib/python3.12/site-packages (from ipython->jupyter_dash) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /opt/conda/lib/python3.12/site-packages (from ipython->jupyter_dash) (3.0.50)
# Requirement already satisfied: pygments>=2.4.0 in /opt/conda/lib/python3.12/site-packages (from ipython->jupyter_dash) (2.19.1)
# Requirement already satisfied: stack_data in /opt/conda/lib/python3.12/site-packages (from ipython->jupyter_dash) (0.6.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests->jupyter_dash) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.12/site-packages (from requests->jupyter_dash) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.12/site-packages (from requests->jupyter_dash) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.12/site-packages (from requests->jupyter_dash) (2024.12.14)
# Requirement already satisfied: six>=1.7.0 in /opt/conda/lib/python3.12/site-packages (from retrying->jupyter_dash) (1.17.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /opt/conda/lib/python3.12/site-packages (from jedi>=0.16->ipython->jupyter_dash) (0.8.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.12/site-packages (from Jinja2>=3.1.2->flask->jupyter_dash) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.12/site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter_dash) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in /opt/conda/lib/python3.12/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter_dash) (4.3.6)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/lib/python3.12/site-packages (from pexpect>4.3->ipython->jupyter_dash) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython->jupyter_dash) (0.2.13)
# Requirement already satisfied: brotli in /opt/conda/lib/python3.12/site-packages (from flask-compress->dash->jupyter_dash) (1.1.0)
# Requirement already satisfied: zstandard in /opt/conda/lib/python3.12/site-packages (from flask-compress->dash->jupyter_dash) (0.23.0)
# Requirement already satisfied: narwhals>=1.15.1 in /opt/conda/lib/python3.12/site-packages (from plotly->dash->jupyter_dash) (1.27.1)
# Requirement already satisfied: executing>=1.2.0 in /opt/conda/lib/python3.12/site-packages (from stack_data->ipython->jupyter_dash) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/conda/lib/python3.12/site-packages (from stack_data->ipython->jupyter_dash) (3.0.0)
# Requirement already satisfied: pure_eval in /opt/conda/lib/python3.12/site-packages (from stack_data->ipython->jupyter_dash) (0.2.3)
# Requirement already satisfied: plotly in /opt/conda/lib/python3.12/site-packages (6.0.0)
# Requirement already satisfied: narwhals>=1.15.1 in /opt/conda/lib/python3.12/site-packages (from plotly) (1.27.1)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.12/site-packages (from plotly) (24.2)
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[11], line 9
#       5 get_ipython().system('pip install --upgrade plotly')
#       8 import pandas as pd
# ----> 9 import dash
#      10 import dash_html_components as html
#      11 import dash_core_components as dcc
#
# File /opt/conda/lib/python3.12/site-packages/dash/__init__.py:5
#       1 # pylint: disable=C0413
#       2 # __plotly_dash is for the "make sure you don't have a dash.py" check
#       3 # must come before any other imports.
#       4 __plotly_dash = True
# ----> 5 from .dash import Dash, no_update  # noqa: F401,E402
#       6 from . import dependencies  # noqa: F401,E402
#       7 from . import development  # noqa: F401,E402
#
# File /opt/conda/lib/python3.12/site-packages/dash/dash.py:22
#      20 import flask
#      21 from flask_compress import Compress
# ---> 22 from werkzeug.debug.tbtools import get_current_traceback
#      23 from pkg_resources import get_distribution, parse_version
#      25 import plotly
#
# ImportError: cannot import name 'get_current_traceback' from 'werkzeug.debug.tbtools' (/opt/conda/lib/python3.12/site-packages/werkzeug/debug/tbtools.py)

# %%
# !pip show werkzeug
# Out:
# Name: Werkzeug
# Version: 3.0.6
# Summary: The comprehensive WSGI web application library.
# Home-page:
# Author:
# Author-email:
# License:
# Location: /opt/conda/lib/python3.12/site-packages
# Requires: MarkupSafe
# Required-by: Flask

# %%
# !pip install werkzeug==2.0.3
# Out:
# Collecting werkzeug==2.0.3
#   Downloading Werkzeug-2.0.3-py3-none-any.whl.metadata (4.5 kB)
# Downloading Werkzeug-2.0.3-py3-none-any.whl (289 kB)
# Installing collected packages: werkzeug
#   Attempting uninstall: werkzeug
#     Found existing installation: Werkzeug 3.0.6
#     Uninstalling Werkzeug-3.0.6:
#       Successfully uninstalled Werkzeug-3.0.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# flask 3.0.3 requires Werkzeug>=3.0.0, but you have werkzeug 2.0.3 which is incompatible.
# Successfully installed werkzeug-2.0.3

# %%
# !pip install dash==1.19.0  

# !pip install jupyter_dash 

# !pip install --upgrade plotly


import pandas as pd
import dash
import dash_html_components as html
import dash_core_components as dcc
from dash.dependencies import Input, Output
from jupyter_dash import JupyterDash
import plotly.graph_objects as go

spacex_df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_dash.csv")
max_payload = spacex_df['Payload Mass (kg)'].max()
min_payload = spacex_df['Payload Mass (kg)'].min()

# Create a dash application
app = JupyterDash(__name__)

# Create an app layout
app.layout = html.Div(children=[
    html.H1('SpaceX Launch Records Dash',
            style={'textAlign': 'center', 'color': '#503D36','font-size': 40}),
 
    # TASK 1: Add a dropdown list to enable Launch Site selection
    dcc.Dropdown(
        id='site-dropdown',
        options=[
            {'label': 'All Sites', 'value': 'ALL'},
            {'label': 'CCAFS LC-40', 'value': 'CCAFS LC-40'},
            {'label': 'CCAFS SLC-40', 'value': 'CCAFS SLC-40'},
            {'label': 'KSC LC-39A', 'value': 'KSC LC-39A'},
            {'label': 'VAFB SLC-4E', 'value': 'VAFB SLC-4E'}
        ],
        value='ALL',
        placeholder="Place holder site here",
        searchable=True
    ),
    html.Br(),
 
    # TASK 2: Add a pie chart to show the total successful launches count for all sites
    html.Div(dcc.Graph(id='success-pie-chart')),
    html.Br(),
 
    html.P("Payload range (Kg):"),
    dcc.RangeSlider(
        id='payload-slider',
        min=0, 
        max=10000, 
        step=1000,
        marks={0: '0(Kg)',2500: '2500 (Kg)', 5000: '5000 (Kg)',7500: '7500 (Kg)', 10000: '10000 (Kg)'},
        value=[min_payload, max_payload]
    ),
 
     # TASK 4: Add a scatter chart to show the correlation between payload and launch success
     html.Div(dcc.Graph(id='success-payload-scatter-chart')),
    ])
 

# TASK 2:
@app.callback(
    Output(component_id='success-pie-chart', component_property='figure'),
    Input(component_id='site-dropdown', component_property='value')
)
def get_pie_chart(entered_site):
    filtered_df = spacex_df
    if entered_site == 'ALL':
        fig = px.pie(filtered_df, values='class', 
                    names='Launch Site', 
                    title='Total Successful Launches by Site')
    else:
        filtered_df = spacex_df[spacex_df['Launch Site'] == entered_site]
        filtered_df = filtered_df.groupby(['Launch Site','class']).size().reset_index(name='class count')
        fig = px.pie(filtered_df, values='class count', 
                     names='class',
                     title=f'Total Sucessful Launches for Site {entered_site}')
    return fig

# TASK 4:
@app.callback(
    Output(component_id='success-payload-scatter-chart', component_property='figure'),
    [Input(component_id='site-dropdown', component_property='value'), 
    Input(component_id="payload-slider", component_property="value")]
)
def get_scatter_chart(entered_site, payload_range):
    filtered_df = spacex_df[(spacex_df['Payload Mass (kg)']>= payload_range[0]) &
                            (spacex_df['Payload Mass (kg)']<= payload_range[1])]
    if entered_site == 'ALL':
        fig = px.scatter(filtered_df, x='Payload Mass (kg)', y='class',
                         color='Booster Version Category',
                         title='Payload vs. Success for All Sites')
    else:
        filtered_df = filtered_df[filtered_df['Launch Site']== entered_site]
        fig = px.scatter(filtered_df, x='Payload Mass (kg)', y='class',
                         color='Booster Version Category',
                         title=f'Payload vs. Success for site {entered_site}')
    return fig

# Run the app
if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
# Requirement already satisfied: dash==1.19.0 in /opt/conda/lib/python3.12/site-packages (1.19.0)
# Requirement already satisfied: Flask>=1.0.4 in /opt/conda/lib/python3.12/site-packages (from dash==1.19.0) (3.0.3)
# Requirement already satisfied: flask-compress in /opt/conda/lib/python3.12/site-packages (from dash==1.19.0) (1.17)
# Requirement already satisfied: plotly in /opt/conda/lib/python3.12/site-packages (from dash==1.19.0) (6.0.0)
# Requirement already satisfied: dash_renderer==1.9.0 in /opt/conda/lib/python3.12/site-packages (from dash==1.19.0) (1.9.0)
# Requirement already satisfied: dash-core-components==1.15.0 in /opt/conda/lib/python3.12/site-packages (from dash==1.19.0) (1.15.0)
# Requirement already satisfied: dash-html-components==1.1.2 in /opt/conda/lib/python3.12/site-packages (from dash==1.19.0) (1.1.2)
# Requirement already satisfied: dash-table==4.11.2 in /opt/conda/lib/python3.12/site-packages (from dash==1.19.0) (4.11.2)
# Requirement already satisfied: future in /opt/conda/lib/python3.12/site-packages (from dash==1.19.0) (1.0.0)
# Collecting Werkzeug>=3.0.0 (from Flask>=1.0.4->dash==1.19.0)
#   Using cached werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: Jinja2>=3.1.2 in /opt/conda/lib/python3.12/site-packages (from Flask>=1.0.4->dash==1.19.0) (3.1.5)
# Requirement already satisfied: itsdangerous>=2.1.2 in /opt/conda/lib/python3.12/site-packages (from Flask>=1.0.4->dash==1.19.0) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in /opt/conda/lib/python3.12/site-packages (from Flask>=1.0.4->dash==1.19.0) (8.1.8)
# Requirement already satisfied: blinker>=1.6.2 in /opt/conda/lib/python3.12/site-packages (from Flask>=1.0.4->dash==1.19.0) (1.9.0)
# Requirement already satisfied: brotli in /opt/conda/lib/python3.12/site-packages (from flask-compress->dash==1.19.0) (1.1.0)
# Requirement already satisfied: zstandard in /opt/conda/lib/python3.12/site-packages (from flask-compress->dash==1.19.0) (0.23.0)
# Requirement already satisfied: narwhals>=1.15.1 in /opt/conda/lib/python3.12/site-packages (from plotly->dash==1.19.0) (1.27.1)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.12/site-packages (from plotly->dash==1.19.0) (24.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.12/site-packages (from Jinja2>=3.1.2->Flask>=1.0.4->dash==1.19.0) (3.0.2)
# Downloading werkzeug-3.1.3-py3-none-any.whl (224 kB)
# Installing collected packages: Werkzeug
#   Attempting uninstall: Werkzeug
#     Found existing installation: Werkzeug 2.0.3
#     Uninstalling Werkzeug-2.0.3:
#       Successfully uninstalled Werkzeug-2.0.3
# Successfully installed Werkzeug-3.1.3
# Requirement already satisfied: jupyter_dash in /opt/conda/lib/python3.12/site-packages (0.4.2)
# Requirement already satisfied: dash in /opt/conda/lib/python3.12/site-packages (from jupyter_dash) (1.19.0)
# Requirement already satisfied: requests in /opt/conda/lib/python3.12/site-packages (from jupyter_dash) (2.32.3)
# Requirement already satisfied: flask in /opt/conda/lib/python3.12/site-packages (from jupyter_dash) (3.0.3)
# Requirement already satisfied: retrying in /opt/conda/lib/python3.12/site-packages (from jupyter_dash) (1.3.4)
# Requirement already satisfied: ipython in /opt/conda/lib/python3.12/site-packages (from jupyter_dash) (8.31.0)
# Requirement already satisfied: ipykernel in /opt/conda/lib/python3.12/site-packages (from jupyter_dash) (6.29.5)
# Requirement already satisfied: ansi2html in /opt/conda/lib/python3.12/site-packages (from jupyter_dash) (1.9.2)
# Requirement already satisfied: nest-asyncio in /opt/conda/lib/python3.12/site-packages (from jupyter_dash) (1.6.0)
# Requirement already satisfied: flask-compress in /opt/conda/lib/python3.12/site-packages (from dash->jupyter_dash) (1.17)
# Requirement already satisfied: plotly in /opt/conda/lib/python3.12/site-packages (from dash->jupyter_dash) (6.0.0)
# Requirement already satisfied: dash_renderer==1.9.0 in /opt/conda/lib/python3.12/site-packages (from dash->jupyter_dash) (1.9.0)
# Requirement already satisfied: dash-core-components==1.15.0 in /opt/conda/lib/python3.12/site-packages (from dash->jupyter_dash) (1.15.0)
# Requirement already satisfied: dash-html-components==1.1.2 in /opt/conda/lib/python3.12/site-packages (from dash->jupyter_dash) (1.1.2)
# Requirement already satisfied: dash-table==4.11.2 in /opt/conda/lib/python3.12/site-packages (from dash->jupyter_dash) (4.11.2)
# Requirement already satisfied: future in /opt/conda/lib/python3.12/site-packages (from dash->jupyter_dash) (1.0.0)
# Requirement already satisfied: Werkzeug>=3.0.0 in /opt/conda/lib/python3.12/site-packages (from flask->jupyter_dash) (3.1.3)
# Requirement already satisfied: Jinja2>=3.1.2 in /opt/conda/lib/python3.12/site-packages (from flask->jupyter_dash) (3.1.5)
# Requirement already satisfied: itsdangerous>=2.1.2 in /opt/conda/lib/python3.12/site-packages (from flask->jupyter_dash) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in /opt/conda/lib/python3.12/site-packages (from flask->jupyter_dash) (8.1.8)
# Requirement already satisfied: blinker>=1.6.2 in /opt/conda/lib/python3.12/site-packages (from flask->jupyter_dash) (1.9.0)
# Requirement already satisfied: comm>=0.1.1 in /opt/conda/lib/python3.12/site-packages (from ipykernel->jupyter_dash) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /opt/conda/lib/python3.12/site-packages (from ipykernel->jupyter_dash) (1.8.12)
# Requirement already satisfied: jupyter-client>=6.1.12 in /opt/conda/lib/python3.12/site-packages (from ipykernel->jupyter_dash) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /opt/conda/lib/python3.12/site-packages (from ipykernel->jupyter_dash) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /opt/conda/lib/python3.12/site-packages (from ipykernel->jupyter_dash) (0.1.7)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.12/site-packages (from ipykernel->jupyter_dash) (24.2)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.12/site-packages (from ipykernel->jupyter_dash) (6.1.1)
# Requirement already satisfied: pyzmq>=24 in /opt/conda/lib/python3.12/site-packages (from ipykernel->jupyter_dash) (26.2.0)
# Requirement already satisfied: tornado>=6.1 in /opt/conda/lib/python3.12/site-packages (from ipykernel->jupyter_dash) (6.4.2)
# Requirement already satisfied: traitlets>=5.4.0 in /opt/conda/lib/python3.12/site-packages (from ipykernel->jupyter_dash) (5.14.3)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.12/site-packages (from ipython->jupyter_dash) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/lib/python3.12/site-packages (from ipython->jupyter_dash) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/lib/python3.12/site-packages (from ipython->jupyter_dash) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /opt/conda/lib/python3.12/site-packages (from ipython->jupyter_dash) (3.0.50)
# Requirement already satisfied: pygments>=2.4.0 in /opt/conda/lib/python3.12/site-packages (from ipython->jupyter_dash) (2.19.1)
# Requirement already satisfied: stack_data in /opt/conda/lib/python3.12/site-packages (from ipython->jupyter_dash) (0.6.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests->jupyter_dash) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.12/site-packages (from requests->jupyter_dash) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.12/site-packages (from requests->jupyter_dash) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.12/site-packages (from requests->jupyter_dash) (2024.12.14)
# Requirement already satisfied: six>=1.7.0 in /opt/conda/lib/python3.12/site-packages (from retrying->jupyter_dash) (1.17.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /opt/conda/lib/python3.12/site-packages (from jedi>=0.16->ipython->jupyter_dash) (0.8.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.12/site-packages (from Jinja2>=3.1.2->flask->jupyter_dash) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.12/site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter_dash) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in /opt/conda/lib/python3.12/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter_dash) (4.3.6)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/lib/python3.12/site-packages (from pexpect>4.3->ipython->jupyter_dash) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython->jupyter_dash) (0.2.13)
# Requirement already satisfied: brotli in /opt/conda/lib/python3.12/site-packages (from flask-compress->dash->jupyter_dash) (1.1.0)
# Requirement already satisfied: zstandard in /opt/conda/lib/python3.12/site-packages (from flask-compress->dash->jupyter_dash) (0.23.0)
# Requirement already satisfied: narwhals>=1.15.1 in /opt/conda/lib/python3.12/site-packages (from plotly->dash->jupyter_dash) (1.27.1)
# Requirement already satisfied: executing>=1.2.0 in /opt/conda/lib/python3.12/site-packages (from stack_data->ipython->jupyter_dash) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/conda/lib/python3.12/site-packages (from stack_data->ipython->jupyter_dash) (3.0.0)
# Requirement already satisfied: pure_eval in /opt/conda/lib/python3.12/site-packages (from stack_data->ipython->jupyter_dash) (0.2.3)
# Requirement already satisfied: plotly in /opt/conda/lib/python3.12/site-packages (6.0.0)
# Requirement already satisfied: narwhals>=1.15.1 in /opt/conda/lib/python3.12/site-packages (from plotly) (1.27.1)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.12/site-packages (from plotly) (24.2)
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[14], line 9
#       5 get_ipython().system('pip install --upgrade plotly')
#       8 import pandas as pd
# ----> 9 import dash
#      10 import dash_html_components as html
#      11 import dash_core_components as dcc
#
# File /opt/conda/lib/python3.12/site-packages/dash/__init__.py:5
#       1 # pylint: disable=C0413
#       2 # __plotly_dash is for the "make sure you don't have a dash.py" check
#       3 # must come before any other imports.
#       4 __plotly_dash = True
# ----> 5 from .dash import Dash, no_update  # noqa: F401,E402
#       6 from . import dependencies  # noqa: F401,E402
#       7 from . import development  # noqa: F401,E402
#
# File /opt/conda/lib/python3.12/site-packages/dash/dash.py:22
#      20 import flask
#      21 from flask_compress import Compress
# ---> 22 from werkzeug.debug.tbtools import get_current_traceback
#      23 from pkg_resources import get_distribution, parse_version
#      25 import plotly
#
# ImportError: cannot import name 'get_current_traceback' from 'werkzeug.debug.tbtools' (/opt/conda/lib/python3.12/site-packages/werkzeug/debug/tbtools.py)

# %%
# !pip list
# Out:
# Package                         Version
# ------------------------------- --------------
# aiohappyeyeballs                2.4.4
# aiohttp                         3.11.11
# aiosignal                       1.3.2
# alembic                         1.14.1
# annotated-types                 0.7.0
# ansi2html                       1.9.2
# anyio                           4.8.0
# archspec                        0.2.5
# argon2-cffi                     23.1.0
# argon2-cffi-bindings            21.2.0
# arrow                           1.3.0
# astroid                         3.3.8
# asttokens                       3.0.0
# async_generator                 1.10
# async-lru                       2.0.4
# attrs                           25.1.0
# autopep8                        2.0.4
# babel                           2.16.0
# beautifulsoup4                  4.12.3
# bleach                          6.2.0
# blinker                         1.9.0
# boltons                         24.0.0
# Brotli                          1.1.0
# cached-property                 1.5.2
# certifi                         2024.12.14
# certipy                         0.2.1
# cffi                            1.17.1
# charset-normalizer              3.4.1
# click                           8.1.8
# colorama                        0.4.6
# comm                            0.2.2
# conda                           25.1.0
# conda-libmamba-solver           25.1.1
# conda-package-handling          2.4.0
# conda_package_streaming         0.11.0
# cryptography                    44.0.0
# dash                            1.19.0
# dash_core_components            1.15.0
# dash_html_components            1.1.2
# dash_renderer                   1.9.0
# dash_table                      4.11.2
# debugpy                         1.8.12
# decorator                       5.1.1
# defusedxml                      0.7.1
# dill                            0.3.9
# distro                          1.9.0
# docstring-to-markdown           0.15
# entrypoints                     0.4
# exceptiongroup                  1.2.2
# executing                       2.1.0
# fastjsonschema                  2.21.1
# flake8                          7.1.1
# Flask                           3.0.3
# Flask-Compress                  1.17
# fqdn                            1.5.1
# frozendict                      2.4.6
# frozenlist                      1.5.0
# future                          1.0.0
# greenlet                        3.1.1
# h11                             0.14.0
# h2                              4.1.0
# hpack                           4.1.0
# httpcore                        1.0.7
# httpx                           0.28.1
# hyperframe                      6.1.0
# idna                            3.10
# importlib_metadata              8.6.1
# importlib_resources             6.5.2
# ipykernel                       6.29.5
# ipython                         8.31.0
# ipython_genutils                0.2.0
# ipywidgets                      8.1.5
# isoduration                     20.11.0
# isort                           6.0.0
# itsdangerous                    2.2.0
# jedi                            0.19.2
# Jinja2                          3.1.5
# json5                           0.10.0
# jsonpatch                       1.33
# jsonpointer                     3.0.0
# jsonschema                      4.23.0
# jsonschema-specifications       2024.10.1
# jupyter_client                  8.6.3
# jupyter_core                    5.7.2
# jupyter-dash                    0.4.2
# jupyter-events                  0.11.0
# jupyter-lsp                     2.2.5
# jupyter_server                  2.15.0
# jupyter_server_proxy            4.4.0
# jupyter_server_terminals        0.5.3
# jupyterhub                      5.2.1
# jupyterlab                      4.3.4
# jupyterlab-lsp                  5.1.0
# jupyterlab_pygments             0.3.0
# jupyterlab_server               2.27.3
# jupyterlab-spellchecker         0.8.4
# jupyterlab_widgets              3.0.13
# libmambapy                      2.0.5
# Mako                            1.3.8
# MarkupSafe                      3.0.2
# matplotlib-inline               0.1.7
# mccabe                          0.7.0
# menuinst                        2.2.0
# mistune                         3.1.0
# multidict                       6.1.0
# narwhals                        1.27.1
# nbclassic                       1.2.0
# nbclient                        0.10.2
# nbconvert                       7.16.5
# nbformat                        5.10.4
# nest_asyncio                    1.6.0
# notebook                        7.3.2
# notebook_shim                   0.2.4
# numpy                           2.2.3
# oauthlib                        3.2.2
# overrides                       7.7.0
# packaging                       24.2
# pamela                          1.2.0
# pandas                          2.2.3
# pandocfilters                   1.5.0
# parso                           0.8.4
# pexpect                         4.9.0
# pickleshare                     0.7.5
# pip                             25.0
# pkgutil_resolve_name            1.3.10
# platformdirs                    4.3.6
# plotly                          6.0.0
# pluggy                          1.5.0
# prometheus_client               0.21.1
# prompt_toolkit                  3.0.50
# propcache                       0.2.1
# psutil                          6.1.1
# ptyprocess                      0.7.0
# pure_eval                       0.2.3
# pycodestyle                     2.12.1
# pycosat                         0.6.6
# pycparser                       2.22
# pydantic                        2.10.6
# pydantic_core                   2.27.2
# pydocstyle                      6.3.0
# pyflakes                        3.2.0
# Pygments                        2.19.1
# PyJWT                           2.10.1
# pylint                          3.3.4
# PySocks                         1.7.1
# python-dateutil                 2.9.0.post0
# python-json-logger              2.0.7
# python-lsp-jsonrpc              1.1.2
# python-lsp-server               1.12.0
# pytoolconfig                    1.2.5
# pytz                            2024.2
# PyYAML                          6.0.2
# pyzmq                           26.2.0
# referencing                     0.36.2
# requests                        2.32.3
# retrying                        1.3.4
# rfc3339_validator               0.1.4
# rfc3986-validator               0.1.1
# rope                            1.13.0
# rpds-py                         0.22.3
# ruamel.yaml                     0.18.10
# ruamel.yaml.clib                0.2.8
# Send2Trash                      1.8.3
# setuptools                      75.8.0
# simpervisor                     1.0.0
# six                             1.17.0
# skillsnetwork_jupyter_extension 2.3.1
# sniffio                         1.3.1
# snowballstemmer                 2.2.0
# soupsieve                       2.5
# SQLAlchemy                      2.0.37
# stack_data                      0.6.3
# tenacity                        9.0.0
# terminado                       0.18.1
# tinycss2                        1.4.0
# tomli                           2.2.1
# tomlkit                         0.13.2
# tornado                         6.4.2
# tqdm                            4.67.1
# traitlets                       5.14.3
# truststore                      0.10.0
# types-python-dateutil           2.9.0.20241206
# typing_extensions               4.12.2
# typing_utils                    0.1.0
# tzdata                          2025.1
# ujson                           5.10.0
# uri-template                    1.3.0
# urllib3                         2.3.0
# wcwidth                         0.2.13
# webcolors                       24.11.1
# webencodings                    0.5.1
# websocket-client                1.8.0
# Werkzeug                        3.1.3
# whatthepatch                    1.0.7
# wheel                           0.45.1
# widgetsnbextension              4.0.13
# yapf                            0.43.0
# yarl                            1.18.3
# zipp                            3.21.0
# zstandard                       0.23.0

# %%
python -m venv myenv
source myenv/bin/activate  # On Windows, use `myenv\Scripts\activate`
pip install dash werkzeug
# Out:
#   Cell In[1], line 1
#     python -m venv myenv
#               ^
# SyntaxError: invalid syntax

# %%
pip install dash
# Out:
# Collecting dash
#   Downloading dash-2.18.2-py3-none-any.whl.metadata (10 kB)
# Collecting Flask<3.1,>=1.0.4 (from dash)
#   Downloading flask-3.0.3-py3-none-any.whl.metadata (3.2 kB)
# Collecting Werkzeug<3.1 (from dash)
#   Downloading werkzeug-3.0.6-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: plotly>=5.0.0 in /opt/conda/lib/python3.12/site-packages (from dash) (5.24.1)
# Collecting dash-html-components==2.0.0 (from dash)
#   Downloading dash_html_components-2.0.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting dash-core-components==2.0.0 (from dash)
#   Downloading dash_core_components-2.0.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting dash-table==5.0.0 (from dash)
#   Downloading dash_table-5.0.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: importlib-metadata in /opt/conda/lib/python3.12/site-packages (from dash) (8.6.1)
# Requirement already satisfied: typing-extensions>=4.1.1 in /opt/conda/lib/python3.12/site-packages (from dash) (4.12.2)
# Requirement already satisfied: requests in /opt/conda/lib/python3.12/site-packages (from dash) (2.32.3)
# Collecting retrying (from dash)
#   Downloading retrying-1.3.4-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: nest-asyncio in /opt/conda/lib/python3.12/site-packages (from dash) (1.6.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.12/site-packages (from dash) (75.8.0)
# Requirement already satisfied: Jinja2>=3.1.2 in /opt/conda/lib/python3.12/site-packages (from Flask<3.1,>=1.0.4->dash) (3.1.5)
# Collecting itsdangerous>=2.1.2 (from Flask<3.1,>=1.0.4->dash)
#   Downloading itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting click>=8.1.3 (from Flask<3.1,>=1.0.4->dash)
#   Downloading click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: blinker>=1.6.2 in /opt/conda/lib/python3.12/site-packages (from Flask<3.1,>=1.0.4->dash) (1.9.0)
# Requirement already satisfied: tenacity>=6.2.0 in /opt/conda/lib/python3.12/site-packages (from plotly>=5.0.0->dash) (9.0.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.12/site-packages (from plotly>=5.0.0->dash) (24.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/lib/python3.12/site-packages (from Werkzeug<3.1->dash) (3.0.2)
# Requirement already satisfied: zipp>=3.20 in /opt/conda/lib/python3.12/site-packages (from importlib-metadata->dash) (3.21.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests->dash) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.12/site-packages (from requests->dash) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.12/site-packages (from requests->dash) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.12/site-packages (from requests->dash) (2024.12.14)
# Requirement already satisfied: six>=1.7.0 in /opt/conda/lib/python3.12/site-packages (from retrying->dash) (1.17.0)
# Downloading dash-2.18.2-py3-none-any.whl (7.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 150.3 MB/s eta 0:00:00
# Downloading dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Downloading dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Downloading dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# Downloading flask-3.0.3-py3-none-any.whl (101 kB)
# Downloading werkzeug-3.0.6-py3-none-any.whl (227 kB)
# Downloading retrying-1.3.4-py3-none-any.whl (11 kB)
# Downloading click-8.1.8-py3-none-any.whl (98 kB)
# Downloading itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Installing collected packages: dash-table, dash-html-components, dash-core-components, Werkzeug, retrying, itsdangerous, click, Flask, dash
# Successfully installed Flask-3.0.3 Werkzeug-3.0.6 click-8.1.8 dash-2.18.2 dash-core-components-2.0.0 dash-html-components-2.0.0 dash-table-5.0.0 itsdangerous-2.2.0 retrying-1.3.4
# Note: you may need to restart the kernel to use updated packages.

# %%
import dash
from dash import dcc, html
from dash.dependencies import Input, Output

# %%
app = dash.Dash(__name__)

# %%
spacex_df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_dash.csv")
max_payload = spacex_df['Payload Mass (kg)'].max()
min_payload = spacex_df['Payload Mass (kg)'].min()

# Create a dash application
app = JupyterDash(__name__)

# Create an app layout
app.layout = html.Div(children=[
    html.H1('SpaceX Launch Records Dash',
            style={'textAlign': 'center', 'color': '#503D36','font-size': 40}),
 
    # TASK 1: Add a dropdown list to enable Launch Site selection
    dcc.Dropdown(
        id='site-dropdown',
        options=[
            {'label': 'All Sites', 'value': 'ALL'},
            {'label': 'CCAFS LC-40', 'value': 'CCAFS LC-40'},
            {'label': 'CCAFS SLC-40', 'value': 'CCAFS SLC-40'},
            {'label': 'KSC LC-39A', 'value': 'KSC LC-39A'},
            {'label': 'VAFB SLC-4E', 'value': 'VAFB SLC-4E'}
        ],
        value='ALL',
        placeholder="Place holder site here",
        searchable=True
    ),
    html.Br(),
 
    # TASK 2: Add a pie chart to show the total successful launches count for all sites
    html.Div(dcc.Graph(id='success-pie-chart')),
    html.Br(),
 
    html.P("Payload range (Kg):"),
    dcc.RangeSlider(
        id='payload-slider',
        min=0, 
        max=10000, 
        step=1000,
        marks={0: '0(Kg)',2500: '2500 (Kg)', 5000: '5000 (Kg)',7500: '7500 (Kg)', 10000: '10000 (Kg)'},
        value=[min_payload, max_payload]
    ),
 
     # TASK 4: Add a scatter chart to show the correlation between payload and launch success
     html.Div(dcc.Graph(id='success-payload-scatter-chart')),
    ])
 

# TASK 2:
@app.callback(
    Output(component_id='success-pie-chart', component_property='figure'),
    Input(component_id='site-dropdown', component_property='value')
)
def get_pie_chart(entered_site):
    filtered_df = spacex_df
    if entered_site == 'ALL':
        fig = px.pie(filtered_df, values='class', 
                    names='Launch Site', 
                    title='Total Successful Launches by Site')
    else:
        filtered_df = spacex_df[spacex_df['Launch Site'] == entered_site]
        filtered_df = filtered_df.groupby(['Launch Site','class']).size().reset_index(name='class count')
        fig = px.pie(filtered_df, values='class count', 
                     names='class',
                     title=f'Total Sucessful Launches for Site {entered_site}')
    return fig

# TASK 4:
@app.callback(
    Output(component_id='success-payload-scatter-chart', component_property='figure'),
    [Input(component_id='site-dropdown', component_property='value'), 
    Input(component_id="payload-slider", component_property="value")]
)
def get_scatter_chart(entered_site, payload_range):
    filtered_df = spacex_df[(spacex_df['Payload Mass (kg)']>= payload_range[0]) &
                            (spacex_df['Payload Mass (kg)']<= payload_range[1])]
    if entered_site == 'ALL':
        fig = px.scatter(filtered_df, x='Payload Mass (kg)', y='class',
                         color='Booster Version Category',
                         title='Payload vs. Success for All Sites')
    else:
        filtered_df = filtered_df[filtered_df['Launch Site']== entered_site]
        fig = px.scatter(filtered_df, x='Payload Mass (kg)', y='class',
                         color='Booster Version Category',
                         title=f'Payload vs. Success for site {entered_site}')
    return fig

# Run the app
if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 spacex_df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_dash.csv")
#       2 max_payload = spacex_df['Payload Mass (kg)'].max()
#       3 min_payload = spacex_df['Payload Mass (kg)'].min()
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
# !pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-2.2.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (89 kB)
# Collecting numpy>=1.26.0 (from pandas)
#   Downloading numpy-2.2.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.12/site-packages (from pandas) (2024.2)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2025.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-2.2.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.7/12.7 MB 137.4 MB/s eta 0:00:00
# Downloading numpy-2.2.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.1/16.1 MB 176.0 MB/s eta 0:00:00
# Downloading tzdata-2025.1-py2.py3-none-any.whl (346 kB)
# Installing collected packages: tzdata, numpy, pandas
# Successfully installed numpy-2.2.3 pandas-2.2.3 tzdata-2025.1

# %%
import pandas as pd

# %%
spacex_df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_dash.csv")
max_payload = spacex_df['Payload Mass (kg)'].max()
min_payload = spacex_df['Payload Mass (kg)'].min()

# Create a dash application
app = JupyterDash(__name__)

# Create an app layout
app.layout = html.Div(children=[
    html.H1('SpaceX Launch Records Dash',
            style={'textAlign': 'center', 'color': '#503D36','font-size': 40}),
 
    # TASK 1: Add a dropdown list to enable Launch Site selection
    dcc.Dropdown(
        id='site-dropdown',
        options=[
            {'label': 'All Sites', 'value': 'ALL'},
            {'label': 'CCAFS LC-40', 'value': 'CCAFS LC-40'},
            {'label': 'CCAFS SLC-40', 'value': 'CCAFS SLC-40'},
            {'label': 'KSC LC-39A', 'value': 'KSC LC-39A'},
            {'label': 'VAFB SLC-4E', 'value': 'VAFB SLC-4E'}
        ],
        value='ALL',
        placeholder="Place holder site here",
        searchable=True
    ),
    html.Br(),
 
    # TASK 2: Add a pie chart to show the total successful launches count for all sites
    html.Div(dcc.Graph(id='success-pie-chart')),
    html.Br(),
 
    html.P("Payload range (Kg):"),
    dcc.RangeSlider(
        id='payload-slider',
        min=0, 
        max=10000, 
        step=1000,
        marks={0: '0(Kg)',2500: '2500 (Kg)', 5000: '5000 (Kg)',7500: '7500 (Kg)', 10000: '10000 (Kg)'},
        value=[min_payload, max_payload]
    ),
 
     # TASK 4: Add a scatter chart to show the correlation between payload and launch success
     html.Div(dcc.Graph(id='success-payload-scatter-chart')),
    ])
 

# TASK 2:
@app.callback(
    Output(component_id='success-pie-chart', component_property='figure'),
    Input(component_id='site-dropdown', component_property='value')
)
def get_pie_chart(entered_site):
    filtered_df = spacex_df
    if entered_site == 'ALL':
        fig = px.pie(filtered_df, values='class', 
                    names='Launch Site', 
                    title='Total Successful Launches by Site')
    else:
        filtered_df = spacex_df[spacex_df['Launch Site'] == entered_site]
        filtered_df = filtered_df.groupby(['Launch Site','class']).size().reset_index(name='class count')
        fig = px.pie(filtered_df, values='class count', 
                     names='class',
                     title=f'Total Sucessful Launches for Site {entered_site}')
    return fig

# TASK 4:
@app.callback(
    Output(component_id='success-payload-scatter-chart', component_property='figure'),
    [Input(component_id='site-dropdown', component_property='value'), 
    Input(component_id="payload-slider", component_property="value")]
)
def get_scatter_chart(entered_site, payload_range):
    filtered_df = spacex_df[(spacex_df['Payload Mass (kg)']>= payload_range[0]) &
                            (spacex_df['Payload Mass (kg)']<= payload_range[1])]
    if entered_site == 'ALL':
        fig = px.scatter(filtered_df, x='Payload Mass (kg)', y='class',
                         color='Booster Version Category',
                         title='Payload vs. Success for All Sites')
    else:
        filtered_df = filtered_df[filtered_df['Launch Site']== entered_site]
        fig = px.scatter(filtered_df, x='Payload Mass (kg)', y='class',
                         color='Booster Version Category',
                         title=f'Payload vs. Success for site {entered_site}')
    return fig

# Run the app
if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 6
#       3 min_payload = spacex_df['Payload Mass (kg)'].min()
#       5 # Create a dash application
# ----> 6 app = JupyterDash(__name__)
#       8 # Create an app layout
#       9 app.layout = html.Div(children=[
#      10     html.H1('SpaceX Launch Records Dash',
#      11             style={'textAlign': 'center', 'color': '#503D36','font-size': 40}),
#    (...)
#      44      html.Div(dcc.Graph(id='success-payload-scatter-chart')),
#      45     ])
#
# NameError: name 'JupyterDash' is not defined

# %%
# !pip install jupyter-dash
# Out:
# Collecting jupyter-dash
#   Downloading jupyter_dash-0.4.2-py3-none-any.whl.metadata (3.6 kB)
# Collecting dash (from jupyter-dash)
#   Downloading dash-2.18.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: requests in /opt/conda/lib/python3.12/site-packages (from jupyter-dash) (2.32.3)
# Collecting flask (from jupyter-dash)
#   Downloading flask-3.1.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting retrying (from jupyter-dash)
#   Downloading retrying-1.3.4-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: ipython in /opt/conda/lib/python3.12/site-packages (from jupyter-dash) (8.31.0)
# Requirement already satisfied: ipykernel in /opt/conda/lib/python3.12/site-packages (from jupyter-dash) (6.29.5)
# Collecting ansi2html (from jupyter-dash)
#   Downloading ansi2html-1.9.2-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: nest-asyncio in /opt/conda/lib/python3.12/site-packages (from jupyter-dash) (1.6.0)
# Collecting flask (from jupyter-dash)
#   Downloading flask-3.0.3-py3-none-any.whl.metadata (3.2 kB)
# Collecting Werkzeug<3.1 (from dash->jupyter-dash)
#   Downloading werkzeug-3.0.6-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: plotly>=5.0.0 in /opt/conda/lib/python3.12/site-packages (from dash->jupyter-dash) (5.24.1)
# Collecting dash-html-components==2.0.0 (from dash->jupyter-dash)
#   Downloading dash_html_components-2.0.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting dash-core-components==2.0.0 (from dash->jupyter-dash)
#   Downloading dash_core_components-2.0.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting dash-table==5.0.0 (from dash->jupyter-dash)
#   Downloading dash_table-5.0.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: importlib-metadata in /opt/conda/lib/python3.12/site-packages (from dash->jupyter-dash) (8.6.1)
# Requirement already satisfied: typing-extensions>=4.1.1 in /opt/conda/lib/python3.12/site-packages (from dash->jupyter-dash) (4.12.2)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.12/site-packages (from dash->jupyter-dash) (75.8.0)
# Requirement already satisfied: Jinja2>=3.1.2 in /opt/conda/lib/python3.12/site-packages (from flask->jupyter-dash) (3.1.5)
# Collecting itsdangerous>=2.1.2 (from flask->jupyter-dash)
#   Downloading itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting click>=8.1.3 (from flask->jupyter-dash)
#   Downloading click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: blinker>=1.6.2 in /opt/conda/lib/python3.12/site-packages (from flask->jupyter-dash) (1.9.0)
# Requirement already satisfied: comm>=0.1.1 in /opt/conda/lib/python3.12/site-packages (from ipykernel->jupyter-dash) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /opt/conda/lib/python3.12/site-packages (from ipykernel->jupyter-dash) (1.8.12)
# Requirement already satisfied: jupyter-client>=6.1.12 in /opt/conda/lib/python3.12/site-packages (from ipykernel->jupyter-dash) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /opt/conda/lib/python3.12/site-packages (from ipykernel->jupyter-dash) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /opt/conda/lib/python3.12/site-packages (from ipykernel->jupyter-dash) (0.1.7)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.12/site-packages (from ipykernel->jupyter-dash) (24.2)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.12/site-packages (from ipykernel->jupyter-dash) (6.1.1)
# Requirement already satisfied: pyzmq>=24 in /opt/conda/lib/python3.12/site-packages (from ipykernel->jupyter-dash) (26.2.0)
# Requirement already satisfied: tornado>=6.1 in /opt/conda/lib/python3.12/site-packages (from ipykernel->jupyter-dash) (6.4.2)
# Requirement already satisfied: traitlets>=5.4.0 in /opt/conda/lib/python3.12/site-packages (from ipykernel->jupyter-dash) (5.14.3)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.12/site-packages (from ipython->jupyter-dash) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/lib/python3.12/site-packages (from ipython->jupyter-dash) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/lib/python3.12/site-packages (from ipython->jupyter-dash) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /opt/conda/lib/python3.12/site-packages (from ipython->jupyter-dash) (3.0.50)
# Requirement already satisfied: pygments>=2.4.0 in /opt/conda/lib/python3.12/site-packages (from ipython->jupyter-dash) (2.19.1)
# Requirement already satisfied: stack_data in /opt/conda/lib/python3.12/site-packages (from ipython->jupyter-dash) (0.6.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests->jupyter-dash) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.12/site-packages (from requests->jupyter-dash) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.12/site-packages (from requests->jupyter-dash) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.12/site-packages (from requests->jupyter-dash) (2024.12.14)
# Requirement already satisfied: six>=1.7.0 in /opt/conda/lib/python3.12/site-packages (from retrying->jupyter-dash) (1.17.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /opt/conda/lib/python3.12/site-packages (from jedi>=0.16->ipython->jupyter-dash) (0.8.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.12/site-packages (from Jinja2>=3.1.2->flask->jupyter-dash) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.12/site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter-dash) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in /opt/conda/lib/python3.12/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter-dash) (4.3.6)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/lib/python3.12/site-packages (from pexpect>4.3->ipython->jupyter-dash) (0.7.0)
# Requirement already satisfied: tenacity>=6.2.0 in /opt/conda/lib/python3.12/site-packages (from plotly>=5.0.0->dash->jupyter-dash) (9.0.0)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython->jupyter-dash) (0.2.13)
# Requirement already satisfied: zipp>=3.20 in /opt/conda/lib/python3.12/site-packages (from importlib-metadata->dash->jupyter-dash) (3.21.0)
# Requirement already satisfied: executing>=1.2.0 in /opt/conda/lib/python3.12/site-packages (from stack_data->ipython->jupyter-dash) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/conda/lib/python3.12/site-packages (from stack_data->ipython->jupyter-dash) (3.0.0)
# Requirement already satisfied: pure_eval in /opt/conda/lib/python3.12/site-packages (from stack_data->ipython->jupyter-dash) (0.2.3)
# Downloading jupyter_dash-0.4.2-py3-none-any.whl (23 kB)
# Downloading ansi2html-1.9.2-py3-none-any.whl (17 kB)
# Downloading dash-2.18.2-py3-none-any.whl (7.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 97.8 MB/s eta 0:00:00
# Downloading dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Downloading dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Downloading dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# Downloading flask-3.0.3-py3-none-any.whl (101 kB)
# Downloading retrying-1.3.4-py3-none-any.whl (11 kB)
# Downloading click-8.1.8-py3-none-any.whl (98 kB)
# Downloading itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Downloading werkzeug-3.0.6-py3-none-any.whl (227 kB)
# Installing collected packages: dash-table, dash-html-components, dash-core-components, Werkzeug, retrying, itsdangerous, click, ansi2html, flask, dash, jupyter-dash
# Successfully installed Werkzeug-3.0.6 ansi2html-1.9.2 click-8.1.8 dash-2.18.2 dash-core-components-2.0.0 dash-html-components-2.0.0 dash-table-5.0.0 flask-3.0.3 itsdangerous-2.2.0 jupyter-dash-0.4.2 retrying-1.3.4

# %%
from jupyter_dash import JupyterDash

# %%
spacex_df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_dash.csv")
max_payload = spacex_df['Payload Mass (kg)'].max()
min_payload = spacex_df['Payload Mass (kg)'].min()

# Create a dash application
app = JupyterDash(__name__)

# Create an app layout
app.layout = html.Div(children=[
    html.H1('SpaceX Launch Records Dash',
            style={'textAlign': 'center', 'color': '#503D36','font-size': 40}),
 
    # TASK 1: Add a dropdown list to enable Launch Site selection
    dcc.Dropdown(
        id='site-dropdown',
        options=[
            {'label': 'All Sites', 'value': 'ALL'},
            {'label': 'CCAFS LC-40', 'value': 'CCAFS LC-40'},
            {'label': 'CCAFS SLC-40', 'value': 'CCAFS SLC-40'},
            {'label': 'KSC LC-39A', 'value': 'KSC LC-39A'},
            {'label': 'VAFB SLC-4E', 'value': 'VAFB SLC-4E'}
        ],
        value='ALL',
        placeholder="Place holder site here",
        searchable=True
    ),
    html.Br(),
 
    # TASK 2: Add a pie chart to show the total successful launches count for all sites
    html.Div(dcc.Graph(id='success-pie-chart')),
    html.Br(),
 
    html.P("Payload range (Kg):"),
    dcc.RangeSlider(
        id='payload-slider',
        min=0, 
        max=10000, 
        step=1000,
        marks={0: '0(Kg)',2500: '2500 (Kg)', 5000: '5000 (Kg)',7500: '7500 (Kg)', 10000: '10000 (Kg)'},
        value=[min_payload, max_payload]
    ),
 
     # TASK 4: Add a scatter chart to show the correlation between payload and launch success
     html.Div(dcc.Graph(id='success-payload-scatter-chart')),
    ])
 

# TASK 2:
@app.callback(
    Output(component_id='success-pie-chart', component_property='figure'),
    Input(component_id='site-dropdown', component_property='value')
)
def get_pie_chart(entered_site):
    filtered_df = spacex_df
    if entered_site == 'ALL':
        fig = px.pie(filtered_df, values='class', 
                    names='Launch Site', 
                    title='Total Successful Launches by Site')
    else:
        filtered_df = spacex_df[spacex_df['Launch Site'] == entered_site]
        filtered_df = filtered_df.groupby(['Launch Site','class']).size().reset_index(name='class count')
        fig = px.pie(filtered_df, values='class count', 
                     names='class',
                     title=f'Total Sucessful Launches for Site {entered_site}')
    return fig

# TASK 4:
@app.callback(
    Output(component_id='success-payload-scatter-chart', component_property='figure'),
    [Input(component_id='site-dropdown', component_property='value'), 
    Input(component_id="payload-slider", component_property="value")]
)
def get_scatter_chart(entered_site, payload_range):
    filtered_df = spacex_df[(spacex_df['Payload Mass (kg)']>= payload_range[0]) &
                            (spacex_df['Payload Mass (kg)']<= payload_range[1])]
    if entered_site == 'ALL':
        fig = px.scatter(filtered_df, x='Payload Mass (kg)', y='class',
                         color='Booster Version Category',
                         title='Payload vs. Success for All Sites')
    else:
        filtered_df = filtered_df[filtered_df['Launch Site']== entered_site]
        fig = px.scatter(filtered_df, x='Payload Mass (kg)', y='class',
                         color='Booster Version Category',
                         title=f'Payload vs. Success for site {entered_site}')
    return fig

# Run the app
if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
# /opt/conda/lib/python3.12/site-packages/dash/dash.py:579: UserWarning:
#
# JupyterDash is deprecated, use Dash instead.
# See https://dash.plotly.com/dash-in-jupyter for more details.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 9
#       6 app = JupyterDash(__name__)
#       8 # Create an app layout
# ----> 9 app.layout = html.Div(children=[
#      10     html.H1('SpaceX Launch Records Dash',
#      11             style={'textAlign': 'center', 'color': '#503D36','font-size': 40}),
#      12
#      13     # TASK 1: Add a dropdown list to enable Launch Site selection
#      14     dcc.Dropdown(
#      15         id='site-dropdown',
#      16         options=[
#      17             {'label': 'All Sites', 'value': 'ALL'},
#      18             {'label': 'CCAFS LC-40', 'value': 'CCAFS LC-40'},
#      19             {'label': 'CCAFS SLC-40', 'value': 'CCAFS SLC-40'},
#      20             {'label': 'KSC LC-39A', 'value': 'KSC LC-39A'},
#      21             {'label': 'VAFB SLC-4E', 'value': 'VAFB SLC-4E'}
#      22         ],
#      23         value='ALL',
#      24         placeholder="Place holder site here",
#      25         searchable=True
#      26     ),
#      27     html.Br(),
#      28
#      29     # TASK 2: Add a pie chart to show the total successful launches count for all sites
#      30     html.Div(dcc.Graph(id='success-pie-chart')),
#      31     html.Br(),
#      32
#      33     html.P("Payload range (Kg):"),
#      34     dcc.RangeSlider(
#      35         id='payload-slider',
#      36         min=0,
#      37         max=10000,
#      38         step=1000,
#      39         marks={0: '0(Kg)',2500: '2500 (Kg)', 5000: '5000 (Kg)',7500: '7500 (Kg)', 10000: '10000 (Kg)'},
#      40         value=[min_payload, max_payload]
#      41     ),
#      42
#      43      # TASK 4: Add a scatter chart to show the correlation between payload and launch success
#      44      html.Div(dcc.Graph(id='success-payload-scatter-chart')),
#      45     ])
#      48 # TASK 2:
#      49 @app.callback(
#      50     Output(component_id='success-pie-chart', component_property='figure'),
#      51     Input(component_id='site-dropdown', component_property='value')
#      52 )
#      53 def get_pie_chart(entered_site):
#
# NameError: name 'html' is not defined

# %%
from dash import html

# %%
spacex_df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_dash.csv")
max_payload = spacex_df['Payload Mass (kg)'].max()
min_payload = spacex_df['Payload Mass (kg)'].min()

# Create a dash application
app = JupyterDash(__name__)

# Create an app layout
app.layout = html.Div(children=[
    html.H1('SpaceX Launch Records Dash',
            style={'textAlign': 'center', 'color': '#503D36','font-size': 40}),
 
    # TASK 1: Add a dropdown list to enable Launch Site selection
    dcc.Dropdown(
        id='site-dropdown',
        options=[
            {'label': 'All Sites', 'value': 'ALL'},
            {'label': 'CCAFS LC-40', 'value': 'CCAFS LC-40'},
            {'label': 'CCAFS SLC-40', 'value': 'CCAFS SLC-40'},
            {'label': 'KSC LC-39A', 'value': 'KSC LC-39A'},
            {'label': 'VAFB SLC-4E', 'value': 'VAFB SLC-4E'}
        ],
        value='ALL',
        placeholder="Place holder site here",
        searchable=True
    ),
    html.Br(),
 
    # TASK 2: Add a pie chart to show the total successful launches count for all sites
    html.Div(dcc.Graph(id='success-pie-chart')),
    html.Br(),
 
    html.P("Payload range (Kg):"),
    dcc.RangeSlider(
        id='payload-slider',
        min=0, 
        max=10000, 
        step=1000,
        marks={0: '0(Kg)',2500: '2500 (Kg)', 5000: '5000 (Kg)',7500: '7500 (Kg)', 10000: '10000 (Kg)'},
        value=[min_payload, max_payload]
    ),
 
     # TASK 4: Add a scatter chart to show the correlation between payload and launch success
     html.Div(dcc.Graph(id='success-payload-scatter-chart')),
    ])
 

# TASK 2:
@app.callback(
    Output(component_id='success-pie-chart', component_property='figure'),
    Input(component_id='site-dropdown', component_property='value')
)
def get_pie_chart(entered_site):
    filtered_df = spacex_df
    if entered_site == 'ALL':
        fig = px.pie(filtered_df, values='class', 
                    names='Launch Site', 
                    title='Total Successful Launches by Site')
    else:
        filtered_df = spacex_df[spacex_df['Launch Site'] == entered_site]
        filtered_df = filtered_df.groupby(['Launch Site','class']).size().reset_index(name='class count')
        fig = px.pie(filtered_df, values='class count', 
                     names='class',
                     title=f'Total Sucessful Launches for Site {entered_site}')
    return fig

# TASK 4:
@app.callback(
    Output(component_id='success-payload-scatter-chart', component_property='figure'),
    [Input(component_id='site-dropdown', component_property='value'), 
    Input(component_id="payload-slider", component_property="value")]
)
def get_scatter_chart(entered_site, payload_range):
    filtered_df = spacex_df[(spacex_df['Payload Mass (kg)']>= payload_range[0]) &
                            (spacex_df['Payload Mass (kg)']<= payload_range[1])]
    if entered_site == 'ALL':
        fig = px.scatter(filtered_df, x='Payload Mass (kg)', y='class',
                         color='Booster Version Category',
                         title='Payload vs. Success for All Sites')
    else:
        filtered_df = filtered_df[filtered_df['Launch Site']== entered_site]
        fig = px.scatter(filtered_df, x='Payload Mass (kg)', y='class',
                         color='Booster Version Category',
                         title=f'Payload vs. Success for site {entered_site}')
    return fig

# Run the app
if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
# /opt/conda/lib/python3.12/site-packages/dash/dash.py:579: UserWarning:
#
# JupyterDash is deprecated, use Dash instead.
# See https://dash.plotly.com/dash-in-jupyter for more details.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 14
#       6 app = JupyterDash(__name__)
#       8 # Create an app layout
#       9 app.layout = html.Div(children=[
#      10     html.H1('SpaceX Launch Records Dash',
#      11             style={'textAlign': 'center', 'color': '#503D36','font-size': 40}),
#      12
#      13     # TASK 1: Add a dropdown list to enable Launch Site selection
# ---> 14     dcc.Dropdown(
#      15         id='site-dropdown',
#      16         options=[
#      17             {'label': 'All Sites', 'value': 'ALL'},
#      18             {'label': 'CCAFS LC-40', 'value': 'CCAFS LC-40'},
#      19             {'label': 'CCAFS SLC-40', 'value': 'CCAFS SLC-40'},
#      20             {'label': 'KSC LC-39A', 'value': 'KSC LC-39A'},
#      21             {'label': 'VAFB SLC-4E', 'value': 'VAFB SLC-4E'}
#      22         ],
#      23         value='ALL',
#      24         placeholder="Place holder site here",
#      25         searchable=True
#      26     ),
#      27     html.Br(),
#      28
#      29     # TASK 2: Add a pie chart to show the total successful launches count for all sites
#      30     html.Div(dcc.Graph(id='success-pie-chart')),
#      31     html.Br(),
#      32
#      33     html.P("Payload range (Kg):"),
#      34     dcc.RangeSlider(
#      35         id='payload-slider',
#      36         min=0,
#      37         max=10000,
#      38         step=1000,
#      39         marks={0: '0(Kg)',2500: '2500 (Kg)', 5000: '5000 (Kg)',7500: '7500 (Kg)', 10000: '10000 (Kg)'},
#      40         value=[min_payload, max_payload]
#      41     ),
#      42
#      43      # TASK 4: Add a scatter chart to show the correlation between payload and launch success
#      44      html.Div(dcc.Graph(id='success-payload-scatter-chart')),
#      45     ])
#      48 # TASK 2:
#      49 @app.callback(
#      50     Output(component_id='success-pie-chart', component_property='figure'),
#      51     Input(component_id='site-dropdown', component_property='value')
#      52 )
#      53 def get_pie_chart(entered_site):
#
# NameError: name 'dcc' is not defined

# %%
from dash import dcc

# %%
spacex_df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_dash.csv")
max_payload = spacex_df['Payload Mass (kg)'].max()
min_payload = spacex_df['Payload Mass (kg)'].min()

# Create a dash application
app = JupyterDash(__name__)

# Create an app layout
app.layout = html.Div(children=[
    html.H1('SpaceX Launch Records Dash',
            style={'textAlign': 'center', 'color': '#503D36','font-size': 40}),
 
    # TASK 1: Add a dropdown list to enable Launch Site selection
    dcc.Dropdown(
        id='site-dropdown',
        options=[
            {'label': 'All Sites', 'value': 'ALL'},
            {'label': 'CCAFS LC-40', 'value': 'CCAFS LC-40'},
            {'label': 'CCAFS SLC-40', 'value': 'CCAFS SLC-40'},
            {'label': 'KSC LC-39A', 'value': 'KSC LC-39A'},
            {'label': 'VAFB SLC-4E', 'value': 'VAFB SLC-4E'}
        ],
        value='ALL',
        placeholder="Place holder site here",
        searchable=True
    ),
    html.Br(),
 
    # TASK 2: Add a pie chart to show the total successful launches count for all sites
    html.Div(dcc.Graph(id='success-pie-chart')),
    html.Br(),
 
    html.P("Payload range (Kg):"),
    dcc.RangeSlider(
        id='payload-slider',
        min=0, 
        max=10000, 
        step=1000,
        marks={0: '0(Kg)',2500: '2500 (Kg)', 5000: '5000 (Kg)',7500: '7500 (Kg)', 10000: '10000 (Kg)'},
        value=[min_payload, max_payload]
    ),
 
     # TASK 4: Add a scatter chart to show the correlation between payload and launch success
     html.Div(dcc.Graph(id='success-payload-scatter-chart')),
    ])
 

# TASK 2:
@app.callback(
    Output(component_id='success-pie-chart', component_property='figure'),
    Input(component_id='site-dropdown', component_property='value')
)
def get_pie_chart(entered_site):
    filtered_df = spacex_df
    if entered_site == 'ALL':
        fig = px.pie(filtered_df, values='class', 
                    names='Launch Site', 
                    title='Total Successful Launches by Site')
    else:
        filtered_df = spacex_df[spacex_df['Launch Site'] == entered_site]
        filtered_df = filtered_df.groupby(['Launch Site','class']).size().reset_index(name='class count')
        fig = px.pie(filtered_df, values='class count', 
                     names='class',
                     title=f'Total Sucessful Launches for Site {entered_site}')
    return fig

# TASK 4:
@app.callback(
    Output(component_id='success-payload-scatter-chart', component_property='figure'),
    [Input(component_id='site-dropdown', component_property='value'), 
    Input(component_id="payload-slider", component_property="value")]
)
def get_scatter_chart(entered_site, payload_range):
    filtered_df = spacex_df[(spacex_df['Payload Mass (kg)']>= payload_range[0]) &
                            (spacex_df['Payload Mass (kg)']<= payload_range[1])]
    if entered_site == 'ALL':
        fig = px.scatter(filtered_df, x='Payload Mass (kg)', y='class',
                         color='Booster Version Category',
                         title='Payload vs. Success for All Sites')
    else:
        filtered_df = filtered_df[filtered_df['Launch Site']== entered_site]
        fig = px.scatter(filtered_df, x='Payload Mass (kg)', y='class',
                         color='Booster Version Category',
                         title=f'Payload vs. Success for site {entered_site}')
    return fig

# Run the app
if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
# /opt/conda/lib/python3.12/site-packages/dash/dash.py:579: UserWarning:
#
# JupyterDash is deprecated, use Dash instead.
# See https://dash.plotly.com/dash-in-jupyter for more details.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 50
#       9 app.layout = html.Div(children=[
#      10     html.H1('SpaceX Launch Records Dash',
#      11             style={'textAlign': 'center', 'color': '#503D36','font-size': 40}),
#    (...)
#      44      html.Div(dcc.Graph(id='success-payload-scatter-chart')),
#      45     ])
#      48 # TASK 2:
#      49 @app.callback(
# ---> 50     Output(component_id='success-pie-chart', component_property='figure'),
#      51     Input(component_id='site-dropdown', component_property='value')
#      52 )
#      53 def get_pie_chart(entered_site):
#      54     filtered_df = spacex_df
#      55     if entered_site == 'ALL':
#
# NameError: name 'Output' is not defined

# %%
from dash.dependencies import Output

# %%
spacex_df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_dash.csv")
max_payload = spacex_df['Payload Mass (kg)'].max()
min_payload = spacex_df['Payload Mass (kg)'].min()

# Create a dash application
app = JupyterDash(__name__)

# Create an app layout
app.layout = html.Div(children=[
    html.H1('SpaceX Launch Records Dash',
            style={'textAlign': 'center', 'color': '#503D36','font-size': 40}),
 
    # TASK 1: Add a dropdown list to enable Launch Site selection
    dcc.Dropdown(
        id='site-dropdown',
        options=[
            {'label': 'All Sites', 'value': 'ALL'},
            {'label': 'CCAFS LC-40', 'value': 'CCAFS LC-40'},
            {'label': 'CCAFS SLC-40', 'value': 'CCAFS SLC-40'},
            {'label': 'KSC LC-39A', 'value': 'KSC LC-39A'},
            {'label': 'VAFB SLC-4E', 'value': 'VAFB SLC-4E'}
        ],
        value='ALL',
        placeholder="Place holder site here",
        searchable=True
    ),
    html.Br(),
 
    # TASK 2: Add a pie chart to show the total successful launches count for all sites
    html.Div(dcc.Graph(id='success-pie-chart')),
    html.Br(),
 
    html.P("Payload range (Kg):"),
    dcc.RangeSlider(
        id='payload-slider',
        min=0, 
        max=10000, 
        step=1000,
        marks={0: '0(Kg)',2500: '2500 (Kg)', 5000: '5000 (Kg)',7500: '7500 (Kg)', 10000: '10000 (Kg)'},
        value=[min_payload, max_payload]
    ),
 
     # TASK 4: Add a scatter chart to show the correlation between payload and launch success
     html.Div(dcc.Graph(id='success-payload-scatter-chart')),
    ])
 

# TASK 2:
@app.callback(
    Output(component_id='success-pie-chart', component_property='figure'),
    Input(component_id='site-dropdown', component_property='value')
)
def get_pie_chart(entered_site):
    filtered_df = spacex_df
    if entered_site == 'ALL':
        fig = px.pie(filtered_df, values='class', 
                    names='Launch Site', 
                    title='Total Successful Launches by Site')
    else:
        filtered_df = spacex_df[spacex_df['Launch Site'] == entered_site]
        filtered_df = filtered_df.groupby(['Launch Site','class']).size().reset_index(name='class count')
        fig = px.pie(filtered_df, values='class count', 
                     names='class',
                     title=f'Total Sucessful Launches for Site {entered_site}')
    return fig

# TASK 4:
@app.callback(
    Output(component_id='success-payload-scatter-chart', component_property='figure'),
    [Input(component_id='site-dropdown', component_property='value'), 
    Input(component_id="payload-slider", component_property="value")]
)
def get_scatter_chart(entered_site, payload_range):
    filtered_df = spacex_df[(spacex_df['Payload Mass (kg)']>= payload_range[0]) &
                            (spacex_df['Payload Mass (kg)']<= payload_range[1])]
    if entered_site == 'ALL':
        fig = px.scatter(filtered_df, x='Payload Mass (kg)', y='class',
                         color='Booster Version Category',
                         title='Payload vs. Success for All Sites')
    else:
        filtered_df = filtered_df[filtered_df['Launch Site']== entered_site]
        fig = px.scatter(filtered_df, x='Payload Mass (kg)', y='class',
                         color='Booster Version Category',
                         title=f'Payload vs. Success for site {entered_site}')
    return fig

# Run the app
if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
# /opt/conda/lib/python3.12/site-packages/dash/dash.py:579: UserWarning:
#
# JupyterDash is deprecated, use Dash instead.
# See https://dash.plotly.com/dash-in-jupyter for more details.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 51
#       9 app.layout = html.Div(children=[
#      10     html.H1('SpaceX Launch Records Dash',
#      11             style={'textAlign': 'center', 'color': '#503D36','font-size': 40}),
#    (...)
#      44      html.Div(dcc.Graph(id='success-payload-scatter-chart')),
#      45     ])
#      48 # TASK 2:
#      49 @app.callback(
#      50     Output(component_id='success-pie-chart', component_property='figure'),
# ---> 51     Input(component_id='site-dropdown', component_property='value')
#      52 )
#      53 def get_pie_chart(entered_site):
#      54     filtered_df = spacex_df
#      55     if entered_site == 'ALL':
#
# NameError: name 'Input' is not defined

# %%
from dash.dependencies import Input

# %%
spacex_df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_dash.csv")
max_payload = spacex_df['Payload Mass (kg)'].max()
min_payload = spacex_df['Payload Mass (kg)'].min()

# Create a dash application
app = JupyterDash(__name__)

# Create an app layout
app.layout = html.Div(children=[
    html.H1('SpaceX Launch Records Dash',
            style={'textAlign': 'center', 'color': '#503D36','font-size': 40}),
 
    # TASK 1: Add a dropdown list to enable Launch Site selection
    dcc.Dropdown(
        id='site-dropdown',
        options=[
            {'label': 'All Sites', 'value': 'ALL'},
            {'label': 'CCAFS LC-40', 'value': 'CCAFS LC-40'},
            {'label': 'CCAFS SLC-40', 'value': 'CCAFS SLC-40'},
            {'label': 'KSC LC-39A', 'value': 'KSC LC-39A'},
            {'label': 'VAFB SLC-4E', 'value': 'VAFB SLC-4E'}
        ],
        value='ALL',
        placeholder="Place holder site here",
        searchable=True
    ),
    html.Br(),
 
    # TASK 2: Add a pie chart to show the total successful launches count for all sites
    html.Div(dcc.Graph(id='success-pie-chart')),
    html.Br(),
 
    html.P("Payload range (Kg):"),
    dcc.RangeSlider(
        id='payload-slider',
        min=0, 
        max=10000, 
        step=1000,
        marks={0: '0(Kg)',2500: '2500 (Kg)', 5000: '5000 (Kg)',7500: '7500 (Kg)', 10000: '10000 (Kg)'},
        value=[min_payload, max_payload]
    ),
 
     # TASK 4: Add a scatter chart to show the correlation between payload and launch success
     html.Div(dcc.Graph(id='success-payload-scatter-chart')),
    ])
 

# TASK 2:
@app.callback(
    Output(component_id='success-pie-chart', component_property='figure'),
    Input(component_id='site-dropdown', component_property='value')
)
def get_pie_chart(entered_site):
    filtered_df = spacex_df
    if entered_site == 'ALL':
        fig = px.pie(filtered_df, values='class', 
                    names='Launch Site', 
                    title='Total Successful Launches by Site')
    else:
        filtered_df = spacex_df[spacex_df['Launch Site'] == entered_site]
        filtered_df = filtered_df.groupby(['Launch Site','class']).size().reset_index(name='class count')
        fig = px.pie(filtered_df, values='class count', 
                     names='class',
                     title=f'Total Sucessful Launches for Site {entered_site}')
    return fig

# TASK 4:
@app.callback(
    Output(component_id='success-payload-scatter-chart', component_property='figure'),
    [Input(component_id='site-dropdown', component_property='value'), 
    Input(component_id="payload-slider", component_property="value")]
)
def get_scatter_chart(entered_site, payload_range):
    filtered_df = spacex_df[(spacex_df['Payload Mass (kg)']>= payload_range[0]) &
                            (spacex_df['Payload Mass (kg)']<= payload_range[1])]
    if entered_site == 'ALL':
        fig = px.scatter(filtered_df, x='Payload Mass (kg)', y='class',
                         color='Booster Version Category',
                         title='Payload vs. Success for All Sites')
    else:
        filtered_df = filtered_df[filtered_df['Launch Site']== entered_site]
        fig = px.scatter(filtered_df, x='Payload Mass (kg)', y='class',
                         color='Booster Version Category',
                         title=f'Payload vs. Success for site {entered_site}')
    return fig

# Run the app
if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
# /opt/conda/lib/python3.12/site-packages/dash/dash.py:579: UserWarning:
#
# JupyterDash is deprecated, use Dash instead.
# See https://dash.plotly.com/dash-in-jupyter for more details.
# Dash app running on http://127.0.0.1:8050/
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
